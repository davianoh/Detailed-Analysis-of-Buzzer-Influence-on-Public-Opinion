# %% [markdown]
# ### Install Libs

# %%
# !pip install transformers==4.31.0
# Out:
# Requirement already satisfied: transformers==4.31.0 in /usr/local/lib/python3.10/dist-packages (4.31.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (2.32.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.31.0) (2024.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.31.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.31.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.31.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.31.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.31.0) (2024.6.2)

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.20.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (16.1.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.5.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2024.5.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.6.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
import pandas as pd
import random as rn
import numpy as np
import os
import tensorflow as tf

from google.colab import drive
drive.mount('/content/drive')

folder_path = '/content/drive/MyDrive/Satria Data pt 2/Semifinal/'
seed_value = 42
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
resolver = tf.distribute.cluster_resolver.TPUClusterResolver()

tf.config.experimental_connect_to_cluster(resolver)
tf.tpu.experimental.initialize_tpu_system(resolver)

strategy = tf.distribute.TPUStrategy(resolver)

# %% [markdown]
# ### Preprocess data

# %%
buzz_df_sample = pd.read_csv('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset/dav/buzz_df_sample_balanced.csv')
non_buzz_df_sample = pd.read_csv('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset/dav/non_buzz_df_sample_balanced.csv')

buzz_df_sample['label'] = 1
non_buzz_df_sample['label'] = 0

df_train = pd.concat([buzz_df_sample, non_buzz_df_sample])
df_train = df_train.sample(frac=1, random_state=42).reset_index(drop=True)
df_train
# Out:
#                                                 content  \
# 0     mahasiswa ngajak debat di jalanan? pilih ganja...
# 1     betul top, bersama pbowogbran yespasti rakyat ...
# 2     pemilu bukan hanya tentang memilih, tapi juga ...
# 3     ganjar-mahfud membangun kepercayaan generasi m...
# 4     rt aslinya acara model desak anies itu bukan m...
# ...                                                 ...
# 5995                   gaspoll terus buat ganjar-mahfud
# 5996  rt kalau anies - imin menang, dan prabowo - gi...
# 5997  rt tidak lagi di tepi jurang, tapi obrolan nya...
# 5998  betul faktanya, masbowogbran palingsejuk seora...
# 5999  ini berlanjut katanya nanti pas nyoblos harus ...
#
#                      created_at  \
# 0     2024-01-03 11:33:50+00:00
# 1     2024-01-20 12:12:34+00:00
# 2     2024-01-21 05:10:13+00:00
# 3     2024-01-04 09:22:17+00:00
# 4     2024-01-24 04:36:05+00:00
# ...                         ...
# 5995  2024-01-09 05:02:28+00:00
# 5996  2024-01-06 17:37:22+00:00
# 5997  2024-01-29 14:22:56+00:00
# 5998  2024-01-17 08:22:59+00:00
# 5999  2024-01-10 14:57:41+00:00
#
#                                            username    tcode  num_retweets  \
# 0     @gFldz8594a1/3rwZT40ovrELxMrSQ88OK94V0gw0Bos=  mention             0
# 1     @hheI7wQBnWCiwxRLDt+NwDuvRZSS98LkJFqqbZl5iZk=    reply             0
# 2     @Vdkp2WMtFHaJbA965/Uod3I/gZENqoPcbRvMgezvfwc=  mention             0
# 3     @7hXgNNxvPb7+D1i+GbLEuSqGVgZ7RoouD0gyRcIymaE=  mention             0
# 4     @5RYtLW+5dh+Qgme5cLz/YI2n2/WzEd19VvyPzDzHxww=       rt             4
# ...                                             ...      ...           ...
# 5995  @l3CIrk9ku4KqNKh/okUPRZFOa9HuvTddzVNHO1ZRgN8=    reply             0
# 5996  @65lSfpSUUk0jbCS9d7zyL+/mNGyo85LFF1z9efYXY/g=       rt             9
# 5997  @eSp3yoymgWrqkI7fMPBERjhEZmn/DPEnnyD1y9ayvoU=       rt          1278
# 5998  @iXaNbHdVVuWsZz4kRjJcnEdBDJ0eBnGK+lgkzuNG3ts=  mention             0
# 5999  @qrxux49vgvfjyscyTBUj7heG3FIcwrk9sfXl3WU4W8g=    reply             0
#
#          frn_cnt      flw_cnt       sts_cnt                  loc   lst_cnt  \
# 0      90.000000    26.000000   1153.000000        PANGKALPINANG  0.000000
# 1      21.000000     9.000000     94.000000                    -  0.000000
# 2       0.000000     9.500000   5741.000000                    -  0.000000
# 3      21.000000    10.000000   1048.000000        Jakarta Barat  0.000000
# 4     552.333333  2382.333333  20532.666667                    -  1.000000
# ...          ...          ...           ...                  ...       ...
# 5995  721.000000   741.000000   5283.000000  Cibinong, Indonesia  0.000000
# 5996  372.000000  4025.750000  16710.000000                    -  3.875000
# 5997  751.823232  1463.222222  25528.570707                    -  1.387879
# 5998  126.000000   102.000000    176.000000                    -  0.000000
# 5999   82.000000    40.000000   2103.000000            Indonesia  0.000000
#
#      lang  appearance_count          nama_re  label
# 0      id                 1                -      1
# 1      id                 1                -      0
# 2      id                 2                -      1
# 3      id                 1                -      1
# 4      id                 3    munierlicious      0
# ...   ...               ...              ...    ...
# 5995   id                 1                -      0
# 5996   id                 8  smile_funcourse      0
# 5997   id               990       BangPino__      0
# 5998   id                 1                -      0
# 5999   id                 1                -      1
#
# [6000 rows x 14 columns]

# %%
dataset = df_train[['content', 'label']]

# %%
from sklearn.model_selection import train_test_split

train_df, val_df = train_test_split(dataset, test_size=0.2, stratify=dataset['label'], random_state=42)

# %%
from datasets import Dataset

train = Dataset.from_pandas(train_df)
val = Dataset.from_pandas(val_df)

# %%
words_count = train_df['content'].apply(lambda x: len(x.split()))

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(words_count, bins=50, edgecolor='black')
plt.title('Distribution of Text Lengths')
plt.xlabel('Length of Text')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Model Ujicoba

# %% [markdown]
# ### Model IndoTweet - 16

# %%
from transformers import AutoTokenizer
from datasets import load_dataset

model_checkpoint = "indolem/indobertweet-base-uncased"

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

train_data = tokenizer(train['content'], padding='max_length', truncation=True, max_length=64, return_tensors="np")
train_data = dict(train_data)  # Because the tokenizer returns a dict subclass
train_labels = np.array(train["label"])

val_data = tokenizer(val['content'], padding='max_length', truncation=True, max_length=64, return_tensors="np")
val_data = dict(val_data)  # Because the tokenizer returns a dict subclass
val_labels = np.array(val["label"])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.10k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/235k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
from transformers import TFAutoModelForSequenceClassification

with strategy.scope():
    model = TFAutoModelForSequenceClassification.from_pretrained(model_checkpoint, from_pt=True)

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=3e-5),
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/445M [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# The batch size will be split among TPU workers
# so we scale it up based on how many of them there are
BATCH_SIZE = 2 * strategy.num_replicas_in_sync

tf_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_labels))
tf_dataset = tf_dataset.shuffle(buffer_size=len(tf_dataset), seed=seed_value)
# You should use drop_remainder on TPU where possible, because a change in the
# batch size will require a new XLA compilation
tf_dataset = tf_dataset.batch(BATCH_SIZE, drop_remainder=True)

tf_dataset
# Out:
# <_BatchDataset element_spec=({'input_ids': TensorSpec(shape=(16, 64), dtype=tf.int64, name=None), 'token_type_ids': TensorSpec(shape=(16, 64), dtype=tf.int64, name=None), 'attention_mask': TensorSpec(shape=(16, 64), dtype=tf.int64, name=None)}, TensorSpec(shape=(16,), dtype=tf.int64, name=None))>

# %%
# The batch size will be split among TPU workers
# so we scale it up based on how many of them there are
BATCH_SIZE = 2 * strategy.num_replicas_in_sync

tf_dataset_val = tf.data.Dataset.from_tensor_slices((val_data, val_labels))
tf_dataset_val = tf_dataset_val.shuffle(buffer_size=len(tf_dataset_val), seed=seed_value)
# You should use drop_remainder on TPU where possible, because a change in the
# batch size will require a new XLA compilation
tf_dataset_val = tf_dataset_val.batch(BATCH_SIZE, drop_remainder=True)

tf_dataset_val
# Out:
# <_BatchDataset element_spec=({'input_ids': TensorSpec(shape=(16, 64), dtype=tf.int64, name=None), 'token_type_ids': TensorSpec(shape=(16, 64), dtype=tf.int64, name=None), 'attention_mask': TensorSpec(shape=(16, 64), dtype=tf.int64, name=None)}, TensorSpec(shape=(16,), dtype=tf.int64, name=None))>

# %%
# saved_filepath = '/content/drive/MyDrive/Satria Data pt 2/Semifinal/Model/IndoTweet_32/checkpoint-IndoTweet_32'

# checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
#     filepath=saved_filepath,  # Path to save the model file
#     monitor='val_sparse_categorical_accuracy',  # Metric to monitor
#     save_best_only=True,  # Save only the best model
#     mode='max',  # Mode to determine if the metric is improving (use 'min' for loss)
#     save_weights_only=True,  # Save only the model weights
#     verbose=1  # Verbosity mode
# )

# early_stopping_callback = tf.keras.callbacks.EarlyStopping(
#     monitor='val_sparse_categorical_accuracy',  # Metric to monitor
#     patience=3,  # Number of epochs with no improvement after which training will be stopped
#     mode='max',  # Mode to determine if the metric is improving (use 'min' for loss)
#     verbose=1  # Verbosity mode
# )

# %%
import time

start_time_serial = time.time()
model.fit(tf_dataset, epochs=5, validation_data=tf_dataset_val)
end_time_serial = time.time()
# Out:
# Epoch 1/5
# 300/300 [==============================] - 100s 95ms/step - loss: 0.4566 - sparse_categorical_accuracy: 0.7600 - val_loss: 0.3731 - val_sparse_categorical_accuracy: 0.8133
# Epoch 2/5
# 300/300 [==============================] - 22s 74ms/step - loss: 0.3077 - sparse_categorical_accuracy: 0.8633 - val_loss: 0.3873 - val_sparse_categorical_accuracy: 0.8075
# Epoch 3/5
# 300/300 [==============================] - 23s 77ms/step - loss: 0.2011 - sparse_categorical_accuracy: 0.9200 - val_loss: 0.4331 - val_sparse_categorical_accuracy: 0.8150
# Epoch 4/5
# 300/300 [==============================] - 22s 74ms/step - loss: 0.0914 - sparse_categorical_accuracy: 0.9679 - val_loss: 0.6166 - val_sparse_categorical_accuracy: 0.8158
# Epoch 5/5
# 300/300 [==============================] - 23s 77ms/step - loss: 0.0527 - sparse_categorical_accuracy: 0.9821 - val_loss: 0.7149 - val_sparse_categorical_accuracy: 0.8017

# %% [markdown]
# ### Model IndoTweet - 24

# %%
from transformers import AutoTokenizer
from datasets import load_dataset

model_checkpoint = "indolem/indobertweet-base-uncased"

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

train_data = tokenizer(train['content'], padding='max_length', truncation=True, max_length=64, return_tensors="np")
train_data = dict(train_data)  # Because the tokenizer returns a dict subclass
train_labels = np.array(train["label"])

val_data = tokenizer(val['content'], padding='max_length', truncation=True, max_length=64, return_tensors="np")
val_data = dict(val_data)  # Because the tokenizer returns a dict subclass
val_labels = np.array(val["label"])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.10k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/235k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
from transformers import TFAutoModelForSequenceClassification

with strategy.scope():
    model = TFAutoModelForSequenceClassification.from_pretrained(model_checkpoint, from_pt=True)

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=3e-5),
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])
# Out:
# pytorch_model.bin:   0%|          | 0.00/445M [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# The batch size will be split among TPU workers
# so we scale it up based on how many of them there are
BATCH_SIZE = 3 * strategy.num_replicas_in_sync

tf_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_labels))
tf_dataset = tf_dataset.shuffle(buffer_size=len(tf_dataset), seed=seed_value)
# You should use drop_remainder on TPU where possible, because a change in the
# batch size will require a new XLA compilation
tf_dataset = tf_dataset.batch(BATCH_SIZE, drop_remainder=True)

tf_dataset
# Out:
# <_BatchDataset element_spec=({'input_ids': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None), 'token_type_ids': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None), 'attention_mask': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None)}, TensorSpec(shape=(24,), dtype=tf.int64, name=None))>

# %%
# The batch size will be split among TPU workers
# so we scale it up based on how many of them there are
BATCH_SIZE = 3 * strategy.num_replicas_in_sync

tf_dataset_val = tf.data.Dataset.from_tensor_slices((val_data, val_labels))
tf_dataset_val = tf_dataset_val.shuffle(buffer_size=len(tf_dataset_val), seed=seed_value)
# You should use drop_remainder on TPU where possible, because a change in the
# batch size will require a new XLA compilation
tf_dataset_val = tf_dataset_val.batch(BATCH_SIZE, drop_remainder=True)

tf_dataset_val
# Out:
# <_BatchDataset element_spec=({'input_ids': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None), 'token_type_ids': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None), 'attention_mask': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None)}, TensorSpec(shape=(24,), dtype=tf.int64, name=None))>

# %%
saved_filepath = '/content/drive/MyDrive/Satria Data pt 2/Semifinal/Model/IndoTweet_24/checkpoint-IndoTweet_24'

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=saved_filepath,  # Path to save the model file
    monitor='val_sparse_categorical_accuracy',  # Metric to monitor
    save_best_only=True,  # Save only the best model
    mode='max',  # Mode to determine if the metric is improving (use 'min' for loss)
    save_weights_only=True,  # Save only the model weights
    verbose=1  # Verbosity mode
)

early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_sparse_categorical_accuracy',  # Metric to monitor
    patience=3,  # Number of epochs with no improvement after which training will be stopped
    mode='max',  # Mode to determine if the metric is improving (use 'min' for loss)
    verbose=1  # Verbosity mode
)

# %%
import time

start_time_serial = time.time()
model.fit(tf_dataset, epochs=10, validation_data=tf_dataset_val, callbacks=[checkpoint_callback, early_stopping_callback])
end_time_serial = time.time()
# Out:
# Epoch 1/5
# 200/200 [==============================] - 94s 110ms/step - loss: 0.4595 - sparse_categorical_accuracy: 0.7581 - val_loss: 0.4028 - val_sparse_categorical_accuracy: 0.7917
# Epoch 2/5
# 200/200 [==============================] - 16s 81ms/step - loss: 0.3039 - sparse_categorical_accuracy: 0.8594 - val_loss: 0.4163 - val_sparse_categorical_accuracy: 0.8042
# Epoch 3/5
# 200/200 [==============================] - 17s 84ms/step - loss: 0.1974 - sparse_categorical_accuracy: 0.9202 - val_loss: 0.4452 - val_sparse_categorical_accuracy: 0.8158
# Epoch 4/5
# 200/200 [==============================] - 16s 79ms/step - loss: 0.0905 - sparse_categorical_accuracy: 0.9690 - val_loss: 0.6442 - val_sparse_categorical_accuracy: 0.8125
# Epoch 5/5
# 200/200 [==============================] - 16s 80ms/step - loss: 0.0512 - sparse_categorical_accuracy: 0.9815 - val_loss: 0.7321 - val_sparse_categorical_accuracy: 0.7992

# %% [markdown]
# ### Model IndoTweet - 32

# %%
from transformers import AutoTokenizer
from datasets import load_dataset

model_checkpoint = "indolem/indobertweet-base-uncased"

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

train_data = tokenizer(train['content'], padding='max_length', truncation=True, max_length=64, return_tensors="np")
train_data = dict(train_data)  # Because the tokenizer returns a dict subclass
train_labels = np.array(train["label"])

val_data = tokenizer(val['content'], padding='max_length', truncation=True, max_length=64, return_tensors="np")
val_data = dict(val_data)  # Because the tokenizer returns a dict subclass
val_labels = np.array(val["label"])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
from transformers import TFAutoModelForSequenceClassification

with strategy.scope():
    model = TFAutoModelForSequenceClassification.from_pretrained(model_checkpoint, from_pt=True)

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=3e-5),
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])
# Out:
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# The batch size will be split among TPU workers
# so we scale it up based on how many of them there are
BATCH_SIZE = 4 * strategy.num_replicas_in_sync

tf_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_labels))
tf_dataset = tf_dataset.shuffle(buffer_size=len(tf_dataset), seed=seed_value)
# You should use drop_remainder on TPU where possible, because a change in the
# batch size will require a new XLA compilation
tf_dataset = tf_dataset.batch(BATCH_SIZE, drop_remainder=True)

tf_dataset
# Out:
# <_BatchDataset element_spec=({'input_ids': TensorSpec(shape=(32, 64), dtype=tf.int64, name=None), 'token_type_ids': TensorSpec(shape=(32, 64), dtype=tf.int64, name=None), 'attention_mask': TensorSpec(shape=(32, 64), dtype=tf.int64, name=None)}, TensorSpec(shape=(32,), dtype=tf.int64, name=None))>

# %%
# The batch size will be split among TPU workers
# so we scale it up based on how many of them there are
BATCH_SIZE = 4 * strategy.num_replicas_in_sync

tf_dataset_val = tf.data.Dataset.from_tensor_slices((val_data, val_labels))
tf_dataset_val = tf_dataset_val.shuffle(buffer_size=len(tf_dataset_val), seed=seed_value)
# You should use drop_remainder on TPU where possible, because a change in the
# batch size will require a new XLA compilation
tf_dataset_val = tf_dataset_val.batch(BATCH_SIZE, drop_remainder=True)

tf_dataset_val
# Out:
# <_BatchDataset element_spec=({'input_ids': TensorSpec(shape=(32, 64), dtype=tf.int64, name=None), 'token_type_ids': TensorSpec(shape=(32, 64), dtype=tf.int64, name=None), 'attention_mask': TensorSpec(shape=(32, 64), dtype=tf.int64, name=None)}, TensorSpec(shape=(32,), dtype=tf.int64, name=None))>

# %%
# saved_filepath = '/content/drive/MyDrive/Satria Data pt 2/Semifinal/Model/IndoTweet_24/checkpoint-IndoTweet_24'

# checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
#     filepath=saved_filepath,  # Path to save the model file
#     monitor='val_sparse_categorical_accuracy',  # Metric to monitor
#     save_best_only=True,  # Save only the best model
#     mode='max',  # Mode to determine if the metric is improving (use 'min' for loss)
#     save_weights_only=True,  # Save only the model weights
#     verbose=1  # Verbosity mode
# )

# early_stopping_callback = tf.keras.callbacks.EarlyStopping(
#     monitor='val_sparse_categorical_accuracy',  # Metric to monitor
#     patience=3,  # Number of epochs with no improvement after which training will be stopped
#     mode='max',  # Mode to determine if the metric is improving (use 'min' for loss)
#     verbose=1  # Verbosity mode
# )

# %%
import time

start_time_serial = time.time()
model.fit(tf_dataset, epochs=5, validation_data=tf_dataset_val)
end_time_serial = time.time()
# Out:
# Epoch 1/5
# 150/150 [==============================] - 90s 122ms/step - loss: 0.4700 - sparse_categorical_accuracy: 0.7515 - val_loss: 0.3745 - val_sparse_categorical_accuracy: 0.7990
# Epoch 2/5
# 150/150 [==============================] - 13s 83ms/step - loss: 0.3092 - sparse_categorical_accuracy: 0.8560 - val_loss: 0.3936 - val_sparse_categorical_accuracy: 0.8133
# Epoch 3/5
# 150/150 [==============================] - 13s 84ms/step - loss: 0.2084 - sparse_categorical_accuracy: 0.9135 - val_loss: 0.4512 - val_sparse_categorical_accuracy: 0.8133
# Epoch 4/5
# 150/150 [==============================] - 12s 83ms/step - loss: 0.1118 - sparse_categorical_accuracy: 0.9619 - val_loss: 0.5151 - val_sparse_categorical_accuracy: 0.8108
# Epoch 5/5
# 150/150 [==============================] - 13s 84ms/step - loss: 0.0497 - sparse_categorical_accuracy: 0.9852 - val_loss: 0.8048 - val_sparse_categorical_accuracy: 0.7872

# %% [markdown]
# ### Model IndoBERT - 16

# %%
from transformers import AutoTokenizer
from datasets import load_dataset

model_checkpoint = "indobenchmark/indobert-base-p1"

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

train_data = tokenizer(train['content'], padding='max_length', truncation=True, max_length=64, return_tensors="np")
train_data = dict(train_data)  # Because the tokenizer returns a dict subclass
train_labels = np.array(train["label"])

val_data = tokenizer(val['content'], padding='max_length', truncation=True, max_length=64, return_tensors="np")
val_data = dict(val_data)  # Because the tokenizer returns a dict subclass
val_labels = np.array(val["label"])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
from transformers import TFAutoModelForSequenceClassification

with strategy.scope():
    model = TFAutoModelForSequenceClassification.from_pretrained(model_checkpoint)

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=3e-5),
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])
# Out:
# tf_model.h5:   0%|          | 0.00/656M [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# Some layers of TFBertForSequenceClassification were not initialized from the model checkpoint at indobenchmark/indobert-base-p1 and are newly initialized: ['classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# The batch size will be split among TPU workers
# so we scale it up based on how many of them there are
BATCH_SIZE = 2 * strategy.num_replicas_in_sync

tf_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_labels))
tf_dataset = tf_dataset.shuffle(buffer_size=len(tf_dataset), seed=seed_value)
# You should use drop_remainder on TPU where possible, because a change in the
# batch size will require a new XLA compilation
tf_dataset = tf_dataset.batch(BATCH_SIZE, drop_remainder=True)

tf_dataset
# Out:
# <_BatchDataset element_spec=({'input_ids': TensorSpec(shape=(16, 64), dtype=tf.int64, name=None), 'token_type_ids': TensorSpec(shape=(16, 64), dtype=tf.int64, name=None), 'attention_mask': TensorSpec(shape=(16, 64), dtype=tf.int64, name=None)}, TensorSpec(shape=(16,), dtype=tf.int64, name=None))>

# %%
# The batch size will be split among TPU workers
# so we scale it up based on how many of them there are
BATCH_SIZE = 2 * strategy.num_replicas_in_sync

tf_dataset_val = tf.data.Dataset.from_tensor_slices((val_data, val_labels))
tf_dataset_val = tf_dataset_val.shuffle(buffer_size=len(tf_dataset_val), seed=seed_value)
# You should use drop_remainder on TPU where possible, because a change in the
# batch size will require a new XLA compilation
tf_dataset_val = tf_dataset_val.batch(BATCH_SIZE, drop_remainder=True)

tf_dataset_val
# Out:
# <_BatchDataset element_spec=({'input_ids': TensorSpec(shape=(16, 64), dtype=tf.int64, name=None), 'token_type_ids': TensorSpec(shape=(16, 64), dtype=tf.int64, name=None), 'attention_mask': TensorSpec(shape=(16, 64), dtype=tf.int64, name=None)}, TensorSpec(shape=(16,), dtype=tf.int64, name=None))>

# %%
# saved_filepath = '/content/drive/MyDrive/Satria Data pt 2/Semifinal/Model/IndoTweet_24/checkpoint-IndoTweet_24'

# checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
#     filepath=saved_filepath,  # Path to save the model file
#     monitor='val_sparse_categorical_accuracy',  # Metric to monitor
#     save_best_only=True,  # Save only the best model
#     mode='max',  # Mode to determine if the metric is improving (use 'min' for loss)
#     save_weights_only=True,  # Save only the model weights
#     verbose=1  # Verbosity mode
# )

# early_stopping_callback = tf.keras.callbacks.EarlyStopping(
#     monitor='val_sparse_categorical_accuracy',  # Metric to monitor
#     patience=3,  # Number of epochs with no improvement after which training will be stopped
#     mode='max',  # Mode to determine if the metric is improving (use 'min' for loss)
#     verbose=1  # Verbosity mode
# )

# %%
import time

start_time_serial = time.time()
model.fit(tf_dataset, epochs=5, validation_data=tf_dataset_val)
end_time_serial = time.time()
# Out:
# Epoch 1/5
# 300/300 [==============================] - 101s 96ms/step - loss: 0.4620 - sparse_categorical_accuracy: 0.7644 - val_loss: 0.3753 - val_sparse_categorical_accuracy: 0.8142
# Epoch 2/5
# 300/300 [==============================] - 24s 80ms/step - loss: 0.3294 - sparse_categorical_accuracy: 0.8467 - val_loss: 0.4215 - val_sparse_categorical_accuracy: 0.7975
# Epoch 3/5
# 300/300 [==============================] - 24s 79ms/step - loss: 0.2347 - sparse_categorical_accuracy: 0.9079 - val_loss: 0.4364 - val_sparse_categorical_accuracy: 0.8042
# Epoch 4/5
# 300/300 [==============================] - 24s 80ms/step - loss: 0.1385 - sparse_categorical_accuracy: 0.9496 - val_loss: 0.4823 - val_sparse_categorical_accuracy: 0.8067
# Epoch 5/5
# 300/300 [==============================] - 24s 80ms/step - loss: 0.0831 - sparse_categorical_accuracy: 0.9685 - val_loss: 0.6906 - val_sparse_categorical_accuracy: 0.7917

# %% [markdown]
# ### Model IndoBERT - 24

# %%
from transformers import AutoTokenizer
from datasets import load_dataset

model_checkpoint = "indobenchmark/indobert-base-p1"

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

train_data = tokenizer(train['content'], padding='max_length', truncation=True, max_length=64, return_tensors="np")
train_data = dict(train_data)  # Because the tokenizer returns a dict subclass
train_labels = np.array(train["label"])

val_data = tokenizer(val['content'], padding='max_length', truncation=True, max_length=64, return_tensors="np")
val_data = dict(val_data)  # Because the tokenizer returns a dict subclass
val_labels = np.array(val["label"])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
from transformers import TFAutoModelForSequenceClassification

with strategy.scope():
    model = TFAutoModelForSequenceClassification.from_pretrained(model_checkpoint)

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=3e-5),
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])
# Out:
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# Some layers of TFBertForSequenceClassification were not initialized from the model checkpoint at indobenchmark/indobert-base-p1 and are newly initialized: ['classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# The batch size will be split among TPU workers
# so we scale it up based on how many of them there are
BATCH_SIZE = 3 * strategy.num_replicas_in_sync

tf_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_labels))
tf_dataset = tf_dataset.shuffle(buffer_size=len(tf_dataset), seed=seed_value)
# You should use drop_remainder on TPU where possible, because a change in the
# batch size will require a new XLA compilation
tf_dataset = tf_dataset.batch(BATCH_SIZE, drop_remainder=True)

tf_dataset
# Out:
# <_BatchDataset element_spec=({'input_ids': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None), 'token_type_ids': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None), 'attention_mask': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None)}, TensorSpec(shape=(24,), dtype=tf.int64, name=None))>

# %%
# The batch size will be split among TPU workers
# so we scale it up based on how many of them there are
BATCH_SIZE = 3 * strategy.num_replicas_in_sync

tf_dataset_val = tf.data.Dataset.from_tensor_slices((val_data, val_labels))
tf_dataset_val = tf_dataset_val.shuffle(buffer_size=len(tf_dataset_val), seed=seed_value)
# You should use drop_remainder on TPU where possible, because a change in the
# batch size will require a new XLA compilation
tf_dataset_val = tf_dataset_val.batch(BATCH_SIZE, drop_remainder=True)

tf_dataset_val
# Out:
# <_BatchDataset element_spec=({'input_ids': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None), 'token_type_ids': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None), 'attention_mask': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None)}, TensorSpec(shape=(24,), dtype=tf.int64, name=None))>

# %%
# saved_filepath = '/content/drive/MyDrive/Satria Data pt 2/Semifinal/Model/IndoTweet_24/checkpoint-IndoTweet_24'

# checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
#     filepath=saved_filepath,  # Path to save the model file
#     monitor='val_sparse_categorical_accuracy',  # Metric to monitor
#     save_best_only=True,  # Save only the best model
#     mode='max',  # Mode to determine if the metric is improving (use 'min' for loss)
#     save_weights_only=True,  # Save only the model weights
#     verbose=1  # Verbosity mode
# )

# early_stopping_callback = tf.keras.callbacks.EarlyStopping(
#     monitor='val_sparse_categorical_accuracy',  # Metric to monitor
#     patience=3,  # Number of epochs with no improvement after which training will be stopped
#     mode='max',  # Mode to determine if the metric is improving (use 'min' for loss)
#     verbose=1  # Verbosity mode
# )

# %%
import time

start_time_serial = time.time()
model.fit(tf_dataset, epochs=5, validation_data=tf_dataset_val)
end_time_serial = time.time()
# Out:
# Epoch 1/5
# 200/200 [==============================] - 97s 109ms/step - loss: 0.4708 - sparse_categorical_accuracy: 0.7608 - val_loss: 0.3815 - val_sparse_categorical_accuracy: 0.8100
# Epoch 2/5
# 200/200 [==============================] - 17s 83ms/step - loss: 0.3396 - sparse_categorical_accuracy: 0.8388 - val_loss: 0.3731 - val_sparse_categorical_accuracy: 0.8133
# Epoch 3/5
# 200/200 [==============================] - 17s 86ms/step - loss: 0.2464 - sparse_categorical_accuracy: 0.8983 - val_loss: 0.4886 - val_sparse_categorical_accuracy: 0.7917
# Epoch 4/5
# 200/200 [==============================] - 17s 85ms/step - loss: 0.1209 - sparse_categorical_accuracy: 0.9567 - val_loss: 0.5177 - val_sparse_categorical_accuracy: 0.7975
# Epoch 5/5
# 200/200 [==============================] - 17s 86ms/step - loss: 0.0670 - sparse_categorical_accuracy: 0.9796 - val_loss: 0.7617 - val_sparse_categorical_accuracy: 0.7917

# %% [markdown]
# ### Model IndoBERT - 32

# %%
from transformers import AutoTokenizer
from datasets import load_dataset

model_checkpoint = "indobenchmark/indobert-base-p1"

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

train_data = tokenizer(train['content'], padding='max_length', truncation=True, max_length=64, return_tensors="np")
train_data = dict(train_data)  # Because the tokenizer returns a dict subclass
train_labels = np.array(train["label"])

val_data = tokenizer(val['content'], padding='max_length', truncation=True, max_length=64, return_tensors="np")
val_data = dict(val_data)  # Because the tokenizer returns a dict subclass
val_labels = np.array(val["label"])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
from transformers import TFAutoModelForSequenceClassification

with strategy.scope():
    model = TFAutoModelForSequenceClassification.from_pretrained(model_checkpoint, from_pt=True)

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=3e-5),
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])
# Out:
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# The batch size will be split among TPU workers
# so we scale it up based on how many of them there are
BATCH_SIZE = 4 * strategy.num_replicas_in_sync

tf_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_labels))
tf_dataset = tf_dataset.shuffle(buffer_size=len(tf_dataset), seed=seed_value)
# You should use drop_remainder on TPU where possible, because a change in the
# batch size will require a new XLA compilation
tf_dataset = tf_dataset.batch(BATCH_SIZE, drop_remainder=True)

tf_dataset
# Out:
# <_BatchDataset element_spec=({'input_ids': TensorSpec(shape=(32, 64), dtype=tf.int64, name=None), 'token_type_ids': TensorSpec(shape=(32, 64), dtype=tf.int64, name=None), 'attention_mask': TensorSpec(shape=(32, 64), dtype=tf.int64, name=None)}, TensorSpec(shape=(32,), dtype=tf.int64, name=None))>

# %%
# The batch size will be split among TPU workers
# so we scale it up based on how many of them there are
BATCH_SIZE = 4 * strategy.num_replicas_in_sync

tf_dataset_val = tf.data.Dataset.from_tensor_slices((val_data, val_labels))
tf_dataset_val = tf_dataset_val.shuffle(buffer_size=len(tf_dataset_val), seed=seed_value)
# You should use drop_remainder on TPU where possible, because a change in the
# batch size will require a new XLA compilation
tf_dataset_val = tf_dataset_val.batch(BATCH_SIZE, drop_remainder=True)

tf_dataset_val
# Out:
# <_BatchDataset element_spec=({'input_ids': TensorSpec(shape=(32, 64), dtype=tf.int64, name=None), 'token_type_ids': TensorSpec(shape=(32, 64), dtype=tf.int64, name=None), 'attention_mask': TensorSpec(shape=(32, 64), dtype=tf.int64, name=None)}, TensorSpec(shape=(32,), dtype=tf.int64, name=None))>

# %%
# saved_filepath = '/content/drive/MyDrive/Satria Data pt 2/Semifinal/Model/IndoTweet_24/checkpoint-IndoTweet_24'

# checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
#     filepath=saved_filepath,  # Path to save the model file
#     monitor='val_sparse_categorical_accuracy',  # Metric to monitor
#     save_best_only=True,  # Save only the best model
#     mode='max',  # Mode to determine if the metric is improving (use 'min' for loss)
#     save_weights_only=True,  # Save only the model weights
#     verbose=1  # Verbosity mode
# )

# early_stopping_callback = tf.keras.callbacks.EarlyStopping(
#     monitor='val_sparse_categorical_accuracy',  # Metric to monitor
#     patience=3,  # Number of epochs with no improvement after which training will be stopped
#     mode='max',  # Mode to determine if the metric is improving (use 'min' for loss)
#     verbose=1  # Verbosity mode
# )

# %%
import time

start_time_serial = time.time()
model.fit(tf_dataset, epochs=5, validation_data=tf_dataset_val)
end_time_serial = time.time()
# Out:
# Epoch 1/5
# 150/150 [==============================] - 97s 126ms/step - loss: 0.4945 - sparse_categorical_accuracy: 0.7454 - val_loss: 0.3886 - val_sparse_categorical_accuracy: 0.8100
# Epoch 2/5
# 150/150 [==============================] - 14s 91ms/step - loss: 0.3438 - sparse_categorical_accuracy: 0.8360 - val_loss: 0.4262 - val_sparse_categorical_accuracy: 0.7956
# Epoch 3/5
# 150/150 [==============================] - 14s 91ms/step - loss: 0.2700 - sparse_categorical_accuracy: 0.8850 - val_loss: 0.4030 - val_sparse_categorical_accuracy: 0.8091
# Epoch 4/5
# 150/150 [==============================] - 14s 91ms/step - loss: 0.1682 - sparse_categorical_accuracy: 0.9369 - val_loss: 0.4407 - val_sparse_categorical_accuracy: 0.8032
# Epoch 5/5
# 150/150 [==============================] - 13s 89ms/step - loss: 0.0946 - sparse_categorical_accuracy: 0.9727 - val_loss: 0.6759 - val_sparse_categorical_accuracy: 0.8100

# %% [markdown]
# ## Inference Data

# %% [markdown]
# ### Model IndoTweet - 24

# %%
from transformers import AutoTokenizer
from datasets import load_dataset

model_checkpoint = "indolem/indobertweet-base-uncased"

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

train_data = tokenizer(train['content'], padding='max_length', truncation=True, max_length=64, return_tensors="np")
train_data = dict(train_data)  # Because the tokenizer returns a dict subclass
train_labels = np.array(train["label"])

val_data = tokenizer(val['content'], padding='max_length', truncation=True, max_length=64, return_tensors="np")
val_data = dict(val_data)  # Because the tokenizer returns a dict subclass
val_labels = np.array(val["label"])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
from transformers import TFAutoModelForSequenceClassification

with strategy.scope():
    model = TFAutoModelForSequenceClassification.from_pretrained(model_checkpoint, from_pt=True)

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=3e-5),
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])
# Out:
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# The batch size will be split among TPU workers
# so we scale it up based on how many of them there are
BATCH_SIZE = 3 * strategy.num_replicas_in_sync

tf_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_labels))
tf_dataset = tf_dataset.shuffle(buffer_size=len(tf_dataset), seed=seed_value)
# You should use drop_remainder on TPU where possible, because a change in the
# batch size will require a new XLA compilation
tf_dataset = tf_dataset.batch(BATCH_SIZE, drop_remainder=True)

tf_dataset
# Out:
# <_BatchDataset element_spec=({'input_ids': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None), 'token_type_ids': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None), 'attention_mask': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None)}, TensorSpec(shape=(24,), dtype=tf.int64, name=None))>

# %%
# The batch size will be split among TPU workers
# so we scale it up based on how many of them there are
BATCH_SIZE = 3 * strategy.num_replicas_in_sync

tf_dataset_val = tf.data.Dataset.from_tensor_slices((val_data, val_labels))
tf_dataset_val = tf_dataset_val.shuffle(buffer_size=len(tf_dataset_val), seed=seed_value)
# You should use drop_remainder on TPU where possible, because a change in the
# batch size will require a new XLA compilation
tf_dataset_val = tf_dataset_val.batch(BATCH_SIZE, drop_remainder=True)

tf_dataset_val
# Out:
# <_BatchDataset element_spec=({'input_ids': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None), 'token_type_ids': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None), 'attention_mask': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None)}, TensorSpec(shape=(24,), dtype=tf.int64, name=None))>

# %%
saved_filepath = '/content/drive/MyDrive/Satria Data pt 2/Semifinal/Model/IndoTweet_24/checkpoint-IndoTweet_24'

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=saved_filepath,  # Path to save the model file
    monitor='val_sparse_categorical_accuracy',  # Metric to monitor
    save_best_only=True,  # Save only the best model
    mode='max',  # Mode to determine if the metric is improving (use 'min' for loss)
    save_weights_only=True,  # Save only the model weights
    verbose=1  # Verbosity mode
)

early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_sparse_categorical_accuracy',  # Metric to monitor
    patience=3,  # Number of epochs with no improvement after which training will be stopped
    mode='max',  # Mode to determine if the metric is improving (use 'min' for loss)
    verbose=1  # Verbosity mode
)

# %%
import time

start_time_serial = time.time()
model.fit(tf_dataset, epochs=5, validation_data=tf_dataset_val, callbacks=[checkpoint_callback, early_stopping_callback])
end_time_serial = time.time()
# Out:
# Epoch 1/5
# 200/200 [==============================] - ETA: 0s - loss: 0.4708 - sparse_categorical_accuracy: 0.7548
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.80667, saving model to /content/drive/MyDrive/Satria Data pt 2/Semifinal/Model/IndoTweet_24/checkpoint-IndoTweet_24
# 200/200 [==============================] - 102s 151ms/step - loss: 0.4708 - sparse_categorical_accuracy: 0.7548 - val_loss: 0.3944 - val_sparse_categorical_accuracy: 0.8067
# Epoch 2/5
# 200/200 [==============================] - ETA: 0s - loss: 0.3213 - sparse_categorical_accuracy: 0.8527
# Epoch 2: val_sparse_categorical_accuracy improved from 0.80667 to 0.81167, saving model to /content/drive/MyDrive/Satria Data pt 2/Semifinal/Model/IndoTweet_24/checkpoint-IndoTweet_24
# 200/200 [==============================] - 24s 121ms/step - loss: 0.3213 - sparse_categorical_accuracy: 0.8527 - val_loss: 0.3879 - val_sparse_categorical_accuracy: 0.8117
# Epoch 3/5
# 200/200 [==============================] - ETA: 0s - loss: 0.2385 - sparse_categorical_accuracy: 0.9010
# Epoch 3: val_sparse_categorical_accuracy improved from 0.81167 to 0.81417, saving model to /content/drive/MyDrive/Satria Data pt 2/Semifinal/Model/IndoTweet_24/checkpoint-IndoTweet_24
# 200/200 [==============================] - 24s 120ms/step - loss: 0.2385 - sparse_categorical_accuracy: 0.9010 - val_loss: 0.4148 - val_sparse_categorical_accuracy: 0.8142
# Epoch 4/5
# 200/200 [==============================] - ETA: 0s - loss: 0.1466 - sparse_categorical_accuracy: 0.9488
# Epoch 4: val_sparse_categorical_accuracy did not improve from 0.81417
# 200/200 [==============================] - 17s 83ms/step - loss: 0.1466 - sparse_categorical_accuracy: 0.9488 - val_loss: 0.5625 - val_sparse_categorical_accuracy: 0.7975
# Epoch 5/5
# 200/200 [==============================] - ETA: 0s - loss: 0.0699 - sparse_categorical_accuracy: 0.9737
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.81417
# 200/200 [==============================] - 17s 83ms/step - loss: 0.0699 - sparse_categorical_accuracy: 0.9737 - val_loss: 0.6299 - val_sparse_categorical_accuracy: 0.8092

# %%
# from sklearn.metrics import confusion_matrix, classification_report
# import seaborn as sns
# import matplotlib.pyplot as plt

# cm = confusion_matrix(val_labels, predicted_classes)


# sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Positive 1', 'Negative 0'], yticklabels=['Positive 1', 'Negative 0'])
# plt.xlabel('Actual')
# plt.ylabel('Predicted')
# plt.title('Confusion Matrix')
# plt.show()


# report = classification_report(val_labels, predicted_classes, digits=5)
# print(report)

# %% [markdown]
# ### Predict

# %%
from transformers import TFAutoModelForSequenceClassification

with strategy.scope():
    model = TFAutoModelForSequenceClassification.from_pretrained(model_checkpoint, from_pt=True)

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=3e-5),
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])

model.load_weights(saved_filepath)

loss, accuracy = model.evaluate(tf_dataset_val)
print(f'Validation loss: {loss}')
print(f'Validation accuracy: {accuracy}')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 50/50 [==============================] - 7s 14ms/step - loss: 0.4148 - sparse_categorical_accuracy: 0.8142
# Validation loss: 0.41479983925819397
# Validation accuracy: 0.8141666650772095

# %%
result_df = pd.read_pickle('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset/dav/result_df_clean.pkl')
test_df = result_df[['username', 'content']]
test_df.head()
# Out:
#                                         username  \
# 0  @be9+Qm5EsBY7VLxMEGgBlOYaT0KrMsiQQLzN5iG2hOY=
# 1  @JVWxyA2fM/S2B0bN/n/buYbHxNqUC91UUX6ShBzub+I=
# 2  @7jB3OiFFcymo1DxD4GO8wR2tuWnQLk+nRHfZmLs1iHo=
# 3  @CDJsmOeil3IHVzBWFKLBs21n0Q2nBvRird0Wb9yxync=
# 4  @X4DJ8WnurWZZIm9IizCEzcdSPvFwGF1pnHnLk1YMgWk=
#
#                                              content
# 0
# 1                                                  !
# 2  ! deretan pesohor dan selebriti yang dukung ga...
# 3  !! iya pakk salah strategii next nya di perbai...
# 4              !! katanya sudah dikembalikan oleh !!

# %%
from datasets import Dataset

test = Dataset.from_pandas(test_df)

# %%
from transformers import AutoTokenizer
from datasets import load_dataset

model_checkpoint = "indolem/indobertweet-base-uncased"

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

test_data = tokenizer(test['content'], padding='max_length', truncation=True, max_length=64, return_tensors="np")
test_data = dict(test_data)  # Because the tokenizer returns a dict subclass
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
predictions = model.predict(test_data)
predictions
# Out:
# 67538/67538 [==============================] - 1208s 18ms/step
# TFSequenceClassifierOutput(loss=None, logits=array([[-0.45156974,  0.59655267],
#        [-0.45569646,  0.59848964],
#        [ 0.17965741, -0.22521684],
#        ...,
#        [-0.99642795,  0.9988195 ],
#        [-0.2876527 ,  0.51387256],
#        [ 0.63540965, -0.44478863]], dtype=float32), hidden_states=None, attentions=None)

# %%
import pickle

with open('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Predictons/pred_indotweet.pkl', 'wb') as f:
    pickle.dump(predictions, f)

# %%
prob_pred = tf.nn.softmax(predictions.logits, axis=-1).numpy()
predicted_classes = np.argmax(prob_pred, axis=-1)
predicted_probabilities = np.max(prob_pred, axis=-1)

# %%
result_df['predicted_buzzer_indotweet'] = predicted_classes

# %% [markdown]
# ##### Cek Predictions

# %%
result_df.loc[result_df['predicted_buzzer_indotweet'] == 1].sample(100, random_state=42)
# Out:
#                                                    content  \
# 1323418  pendukungnya sedang mencuci piring hingga kinc...
# 415597   dul, coba nyebokinnya sambil dijilat.. tainya ...
# 842585   kamu kalau nonton bisa lihat dan dengar dasar ...
# 1885055  tau yg bikin orang2 pada males milih 02? bukan...
# 879707   kebersamaan ganjar-mahfud dan slank menciptaka...
# ...                                                    ...
# 1287527  pas itu pak ganjar topengnya setan, kayak klub...
# 82246    also prabowo "ndasmu etik, goblok, otaknya kur...
# 319875   dalam kebersamaan ganjar pranowo mahfud md, in...
# 1884172  tas tes semoga ganjar-mahfud selalu memberi du...
# 1438799  program "desa cerdas" di bawah kepemimpinan ga...
#
#                        created_at  \
# 1323418 2024-01-10 09:55:32+00:00
# 415597  2024-01-21 17:23:07+00:00
# 842585  2024-01-07 20:15:08+00:00
# 1885055 2024-01-31 17:34:39+00:00
# 879707  2024-01-21 08:11:02+00:00
# ...                           ...
# 1287527 2024-01-09 12:31:16+00:00
# 82246   2024-01-21 03:19:21+00:00
# 319875  2024-01-22 13:10:13+00:00
# 1884172 2024-01-07 13:11:46+00:00
# 1438799 2024-01-23 20:20:13+00:00
#
#                                               username    tcode  num_retweets  \
# 1323418  @AJpfp1dN+Rmop7feTApn/dM3H2CwnFL1V+Yt7Wrht3A=    reply             0
# 415597   @1Dhh7Xh1+yXKPT7+5W4Crjk0A4CwXdsq/xfnl6j9B1k=    reply             0
# 842585   @B+UK4LfW180yJi8NT0jFo1HM9Wl0MMLcyllc5bRDVz8=    reply             0
# 1885055  @eJBfMaHKGAS3X3J8b0ccdctdmQ1OVcLk5Nr4RVYx2Po=    reply             0
# 879707   @JyCiX0zIhWliPQLVPKM5bSO3pOTFsJIvoC+iNOxnR9M=  mention             0
# ...                                                ...      ...           ...
# 1287527  @YNZvBUKKtRxExytAMuTXzzpGNGpAvIC4Q3ZBFfeXBQg=    reply             0
# 82246    @qg/vcjgnCcKtqE+TYPuBizut/yfyuG6Qroh85paPHes=    reply             0
# 319875   @srdqcHagk2sGq/jdVpJ9PQugASwUQU5fRq6xUlpWK/M=  mention             0
# 1884172  @KgdEqtj9C0oqRLvvIGz+opk3hppd8SvOOFtojeqLeLE=  mention             0
# 1438799  @GngmHFMp1WOeiWnxM7DDBVm9qu9TKRDf9+bEJN4SJ0M=  mention             0
#
#          frn_cnt  flw_cnt  sts_cnt                  loc  lst_cnt lang  \
# 1323418     32.0     28.0    810.0                    -      0.0   id
# 415597     126.0     41.0    378.0                World      2.0   id
# 842585    1025.0    364.0  15246.0  Bandung, Jawa Barat      1.0   id
# 1885055     12.0      2.0    195.0                    -      0.0   id
# 879707      34.0     10.0   1386.0                Jambi      0.0   id
# ...          ...      ...      ...                  ...      ...  ...
# 1287527   3291.0   4720.0  17084.0  Manchester, England      2.0   id
# 82246      115.0      7.0   1099.0            Indonesia      1.0   id
# 319875       2.0      3.0   5487.0                    -      0.0   id
# 1884172     53.0     32.0   1230.0               Sabang      0.0   id
# 1438799      0.0      5.0   5487.0                    -      0.0   id
#
#          appearance_count nama_re  predicted_buzzer_indotweet
# 1323418                 1       -                           1
# 415597                  1       -                           1
# 842585                  1       -                           1
# 1885055                 1       -                           1
# 879707                  1       -                           1
# ...                   ...     ...                         ...
# 1287527                 1       -                           1
# 82246                   1       -                           1
# 319875                  1       -                           1
# 1884172                 1       -                           1
# 1438799                 1       -                           1
#
# [100 rows x 14 columns]

# %%
result_df.loc[result_df['predicted_buzzer_indotweet'] == 0].sample(100, random_state=42)
# Out:
#                                                    content  \
# 2014094  yakin nih, gengs? percaya sama strategi 'ngele...
# 1079451  masyaallah semoga pak ganjar bisa menjadi pres...
# 169275                                       baca dong pak
# 1607243  rt pak ganjar pranowo menganggap kritikan seba...
# 1492247  rt anies malah di bawah 5 ya...sadis ððð...
# ...                                                    ...
# 1805052  setuju sih, gue hampir kemakan narasi beliau b...
# 1364196  prabagoes: sangat banyak alasan mengapa kita m...
# 974475   ktp sakti ganjar-mahfud!!!! berbagai macam man...
# 1751047  semakin optimis pak ganjar menang ngobrol bar3...
# 255000   boleh jugaaa boleh numpang bilangin ga saya ma...
#
#                        created_at  \
# 2014094 2024-01-08 22:46:33+00:00
# 1079451 2024-01-16 22:08:26+00:00
# 169275  2024-01-23 08:19:20+00:00
# 1607243 2024-01-19 15:19:03+00:00
# 1492247 2024-01-08 12:57:24+00:00
# ...                           ...
# 1805052 2024-01-31 03:01:50+00:00
# 1364196 2024-01-11 22:02:10+00:00
# 974475  2024-01-09 04:54:01+00:00
# 1751047 2024-01-13 10:30:00+00:00
# 255000  2024-01-13 03:20:36+00:00
#
#                                               username    tcode  num_retweets  \
# 2014094  @uUyh6hIoPekQJTSnMc5IJDMht0qDafceXjTDWcjt7QA=  mention             0
# 1079451  @WVT2D3kciAwBxI+NHPnDa/cXbYhRh9GmurSfUj54Fic=    reply             0
# 169275   @ssH5wrz9tV2AOnJ4y6D9YsMQeqnnP+Lzsvx4SC5Z4Us=  mention             0
# 1607243  @7Lwm94rIM1jxl9ocnegacugfBjOTAmWUIw3ePRBDUwU=       rt             4
# 1492247  @JZ52q3B7tUQrpD1ZKwHrJK8VPDxiIjIMBHgQhRQ/c78=       rt             1
# ...                                                ...      ...           ...
# 1805052  @2bRJl5P3EZVgnjVn6Es2g5j4aZW4Xs57EDeyK2Lv7mw=    reply             0
# 1364196  @nC0etgOvRmkywTWwNZ/aaU+N2dZbTkBa0hczAWy/6oY=  mention             0
# 974475   @fAWl1Ijkp1vbayHuxCTWNNOlWZEQLMgvtrqq1rVZ9Ts=  mention             0
# 1751047  @yXihmyAT19JcXQeZD9+FzV1eEYCGY9X3SZn4LZKOslI=  mention             0
# 255000   @yhwxpp9PntKo86pWH9xYmUwHdOuu0872qGZbaNyiU78=    reply             0
#
#              frn_cnt       flw_cnt       sts_cnt           loc    lst_cnt  \
# 2014094    59.000000     37.000000    131.000000          Bima   0.000000
# 1079451     1.000000      3.000000    382.000000             -   0.000000
# 169275    328.000000    177.500000   8062.000000             -   0.500000
# 1607243  1575.666667  13556.333333  84096.666667             -   2.666667
# 1492247  2345.000000  19360.000000  66535.000000     Indonesia  24.000000
# ...              ...           ...           ...           ...        ...
# 1805052   144.000000     66.000000   4246.000000             -   0.000000
# 1364196     0.000000      1.000000    292.000000             -   0.000000
# 974475     11.523810      1.809524    296.619048             -   0.000000
# 1751047    27.000000     27.000000     99.000000  Quantico, VA   0.000000
# 255000     51.000000     35.000000     73.000000             -   0.000000
#
#         lang  appearance_count   nama_re  predicted_buzzer_indotweet
# 2014094   id                 1         -                           0
# 1079451   id                 1         -                           0
# 169275    id                 2         -                           0
# 1607243   id                 3  Denokamu                           0
# 1492247   id                 1   RekjanS                           0
# ...      ...               ...       ...                         ...
# 1805052   id                 1         -                           0
# 1364196   id                 1         -                           0
# 974475    id                21         -                           0
# 1751047   id                 1         -                           0
# 255000    id                 1         -                           0
#
# [100 rows x 14 columns]

# %%
result_df.loc[result_df['predicted_buzzer_indotweet'] == 0].shape
# Out:
# (1173243, 14)

# %%
result_df.loc[result_df['predicted_buzzer_indotweet'] == 1].shape
# Out:
# (987956, 14)
