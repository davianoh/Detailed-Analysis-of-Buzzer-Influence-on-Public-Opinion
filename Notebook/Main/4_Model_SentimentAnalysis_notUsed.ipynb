# %% [markdown]
# ### Import Data

# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')

folder_path = '/content/drive/MyDrive/Satria Data pt 2/Semifinal/'
# Out:
# Mounted at /content/drive

# %%
result_df = pd.read_pickle('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset_Part2/result_df_clean_sent.pkl')
result_df.head()
# Out:
#                                              content  \
# 0
# 1                                                  !
# 2  ! deretan pesohor dan selebriti yang dukung ga...
# 3  !! iya pakk salah strategii next nya di perbai...
# 4              !! katanya sudah dikembalikan oleh !!
#
#                                         real_content  \
# 0  @X3PdsT0s+nosDiSVDq3nQPNxLKQV1ZMBl5NDSXLLnOs= ...
# 1  @9ZwcLHT18/fgudsdN9vmg9J97LmX6RgmUQ41zZwq484= ...
# 2  ! Deretan Pesohor dan Selebriti yang Dukung Ga...
# 3  @04DvPx8s7LBc4cxDKmtXMRGxzcWjux55XJYA4DJpUOQ= ...
# 4  @YKXM72NPxrEQof3YA3UvtB1N7433ER/5HCHcbEdjJi8= ...
#
#                  created_at                                       username  \
# 0 2024-01-31 17:26:28+00:00  @be9+Qm5EsBY7VLxMEGgBlOYaT0KrMsiQQLzN5iG2hOY=
# 1 2024-01-29 16:57:00+00:00  @JVWxyA2fM/S2B0bN/n/buYbHxNqUC91UUX6ShBzub+I=
# 2 2024-01-30 02:03:42+00:00  @7jB3OiFFcymo1DxD4GO8wR2tuWnQLk+nRHfZmLs1iHo=
# 3 2024-01-07 15:57:19+00:00  @CDJsmOeil3IHVzBWFKLBs21n0Q2nBvRird0Wb9yxync=
# 4 2024-01-19 04:19:17+00:00  @X4DJ8WnurWZZIm9IizCEzcdSPvFwGF1pnHnLk1YMgWk=
#
#      tcode  num_retweets      frn_cnt      flw_cnt       sts_cnt        loc  \
# 0    reply            36   696.150781  1543.289555  14114.732016          -
# 1    reply             0   327.000000   208.666667  11230.333333          -
# 2  mention             0    28.000000     2.000000     75.000000  Indonesia
# 3    reply             0     2.000000     2.000000    234.000000          -
# 4    reply             0  1347.000000  1390.000000  60962.000000          -
#
#     lst_cnt lang  appearance_count nama_re  \
# 0  1.757412   id              9411       -
# 1  0.000000   id                 3       -
# 2  0.000000   id                 1       -
# 3  0.000000   id                 1       -
# 4  0.000000   id                 1       -
#
#                                             hashtags  \
# 0                                                 []
# 1                                                 []
# 2  [#GanjarMahfud2024, #Kopassos03, #GanjarPresid...
# 3                                                 []
# 4                                                 []
#
#                                        content_surya  \
# 0  @X3PdsT0s+nosDiSVDq3nQPNxLKQV1ZMBl5NDSXLLnOs= ...
# 1  @9ZwcLHT18/fgudsdN9vmg9J97LmX6RgmUQ41zZwq484= ...
# 2  ! Deretan Pesohor dan Selebriti yang Dukung Ga...
# 3  @04DvPx8s7LBc4cxDKmtXMRGxzcWjux55XJYA4DJpUOQ= ...
# 4  @YKXM72NPxrEQof3YA3UvtB1N7433ER/5HCHcbEdjJi8= ...
#
#                                    content_sentiment  \
# 0
# 1                                                  !
# 2  ! deretan pesohor dan selebriti yang dukung ga...
# 3  !! iya pakk salah strategii next nya di perbai...
# 4              !! katanya sudah dikembalikan oleh !!
#
#                                       hashtags_clean
# 0                                                 []
# 1                                                 []
# 2  [Ganjar Mahfud, Kopassos, Ganjar Presiden Raky...
# 3                                                 []
# 4                                                 []

# %%
result_df['tcode'].value_counts()
# Out:
# tcode
# mention    1002090
# reply       957233
# rt          201876
# Name: count, dtype: int64

# %%
# import pickle
# import tensorflow as tf
# import numpy as np

# with open('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Predictons/pred_indotweet.pkl', 'rb') as f:
#     predictions = pickle.load(f)

# with open('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Predictons/pred_xgb.pkl', 'rb') as f:
#     pred_xgb = pickle.load(f)


# prob_pred = tf.nn.softmax(predictions.logits, axis=-1).numpy()
# predicted_classes = np.argmax(prob_pred, axis=-1)
# predicted_probabilities = np.max(prob_pred, axis=-1)


# result_df['pred_buz_xgb'] = pred_xgb
# result_df['pred_buz_indotweet'] = predicted_classes

# buzz_df = result_df.loc[(result_df['pred_buz_xgb'] == 1) & (result_df['pred_buz_indotweet'] == 1)]
# buzz_df.sample(1000, random_state=42)

# %% [markdown]
# ### Create Data Label Based Hashtags

# %% [markdown]
# ##### Anies

# %%
term_anies = ['anies', 'muhaimin', 'paslon1']

pattern_anies = '|'.join(term_anies)

result_df_anies = result_df.loc[result_df['content'].str.contains(pattern_anies, case=False, na=False)]

# %%
hashtag_anies = pd.read_excel('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset_Part2/keyterms_paslon/hashtag_paslon1.xlsx')

hashtag_anies = hashtag_anies[:200]
hashtag_anies['Label'] = hashtag_anies['Label'].fillna(0)
hashtag_anies
# Out:
#      Unnamed: 0                      hashtag   count  Label
# 0             0                 #AMINAjaDulu  398879    0.0
# 1             1           #AniesMuhaimin2024  134312    0.0
# 2             2                  #DesakAnies   85963    0.0
# 3             3                #HaveAniesDay   70925    0.0
# 4             4  #PahitManiesAlwaysWithAnies   70448    0.0
# ..          ...                          ...     ...    ...
# 195         195            #AnieMuhaimin2024     139    0.0
# 196         196               #Anies2ndstage     134    0.0
# 197         197       #AminMenangJudolHilang     132    0.0
# 198         198        #AMINSATUkanIndonesia     129    0.0
# 199         199       #AyoPrabowoGamparAnies     123    1.0
#
# [200 rows x 4 columns]

# %%
hashtag_anies['Label'].value_counts()
# Out:
# Label
# 0.0    186
# 2.0     10
# 1.0      4
# Name: count, dtype: int64

# %% [markdown]
# ######Positif

# %%
hashtag_anies_positif_df = hashtag_anies.loc[hashtag_anies['Label'] == 0]

hashtag_anies_positif = hashtag_anies_positif_df['hashtag'].tolist()

pattern_hashtag_anies_positif = '|'.join(hashtag_anies_positif)

result_df_anies_positif = result_df_anies.loc[result_df_anies['content_sentiment'].str.contains(pattern_hashtag_anies_positif, case=False, na=False)]

# %%
result_df_anies_positif.shape
# Out:
# (0, 18)

# %%
result_df_anies_positif.to_csv('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset/dav/sentiment_hashtag/result_df_anies_positif_v2.csv', index=False)

# %% [markdown]
# ######Negatif

# %%
hashtag_anies_negatif_df = hashtag_anies.loc[hashtag_anies['Label'] == 2]

hashtag_anies_negatif = hashtag_anies_negatif_df['hashtag'].tolist()

pattern_hashtag_anies_negatif = '|'.join(hashtag_anies_negatif)

result_df_anies_negatif = result_df_anies.loc[result_df_anies['content_sentiment'].str.contains(pattern_hashtag_anies_negatif, case=False, na=False)]

# %%
result_df_anies_negatif.shape
# Out:
# (0, 18)

# %%
result_df_anies_negatif.to_csv('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset/dav/sentiment_hashtag/result_df_anies_negatif_v2.csv', index=False)

# %% [markdown]
# ##### Prabowo

# %%
term_prabowo = ['prabowo', 'gibran', 'paslon2']

pattern_prabowo = '|'.join(term_prabowo)

result_df_prabowo = result_df.loc[result_df['content_sentiment'].str.contains(pattern_prabowo, case=False, na=False)]

# %%
hashtag_prabowo = pd.read_excel('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset_Part2/keyterms_paslon/hashtag_paslon2.xlsx')

hashtag_prabowo = hashtag_prabowo[:200]
hashtag_prabowo['Label'] = hashtag_prabowo['Label'].fillna(0)
hashtag_prabowo
# Out:
#      Unnamed: 0                hashtag  count  Label
# 0             0      #AsalBukanPrabowo  80054    2.0
# 1             1          #PrabowoGemoy  45601    0.0
# 2             2               #prabowo  37024    0.0
# 3             3     #JabarTetapPakBowo  29999    0.0
# 4             4  #BersamaPrabowoGibran  24607    0.0
# ..          ...                    ...    ...    ...
# 195         195  #PrabowoGibran4Change     96    0.0
# 196         196   #AslinyaHanyaPrabowo     96    0.0
# 197         197    #Ganjarsikatkorupsi     96    1.0
# 198         198          #prabowopedia     95    0.0
# 199         199     #gibranmasukgolkar     94    0.0
#
# [200 rows x 4 columns]

# %%
hashtag_prabowo['Label'].value_counts()
# Out:
# Label
# 0.0    146
# 2.0     40
# 1.0     14
# Name: count, dtype: int64

# %% [markdown]
# ######Positif

# %%
hashtag_prabowo_positif_df = hashtag_prabowo.loc[hashtag_prabowo['Label'] == 0]

hashtag_prabowo_positif = hashtag_prabowo_positif_df['hashtag'].tolist()

pattern_hashtag_prabowo_positif = '|'.join(hashtag_prabowo_positif)

result_df_prabowo_positif = result_df_prabowo.loc[result_df_prabowo['real_content'].str.contains(pattern_hashtag_prabowo_positif, case=False, na=False)]

# %%
result_df_prabowo_positif.shape
# Out:
# (0, 18)

# %%
result_df_prabowo_positif.to_csv('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset/dav/sentiment_hashtag/result_df_prabowo_positif_v2.csv', index=False)

# %% [markdown]
# ######Negatif

# %%
hashtag_prabowo_negatif_df = hashtag_prabowo.loc[hashtag_prabowo['Label'] == 2]

hashtag_prabowo_negatif = hashtag_prabowo_negatif_df['hashtag'].tolist()

pattern_hashtag_prabowo_negatif = '|'.join(hashtag_prabowo_negatif)

result_df_prabowo_negatif = result_df_prabowo.loc[result_df_prabowo['real_content'].str.contains(pattern_hashtag_prabowo_negatif, case=False, na=False)]

# %%
result_df_prabowo_negatif.shape
# Out:
# (0, 18)

# %%
result_df_prabowo_negatif.to_csv('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset/dav/sentiment_hashtag/result_df_prabowo_negatif_v2.csv', index=False)

# %% [markdown]
# ##### Ganjar

# %%
term_ganjar = ['ganjar', 'mahfud', 'paslon3']

pattern_ganjar = '|'.join(term_ganjar)

result_df_ganjar = result_df.loc[result_df['content'].str.contains(pattern_ganjar, case=False, na=False)]

# %%
hashtag_ganjar = pd.read_excel('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset_Part2/keyterms_paslon/hashtag_paslon3.xlsx')

hashtag_ganjar = hashtag_ganjar[:200]
hashtag_ganjar['Label'] = hashtag_ganjar['Label'].fillna(0)
hashtag_ganjar
# Out:
#      Unnamed: 0                    hashtag   count  Label
# 0             0       #GanjarMahfudRebound  860268    0.0
# 1             1  #GanjarPranowoPilihanUmat  814906    0.0
# 2             2          #GanjarMahfud2024  548682    0.0
# 3             3  #DuluJokowiSekarangGanjar  167675    0.0
# 4             4   #GanjarMahfudM3nangDebat  158257    0.0
# ..          ...                        ...     ...    ...
# 195         195   #PetaniMajuBersamaGanjar     177    0.0
# 196         196              #ganjarin_aja     177    0.0
# 197         197           #GanjarForRakyat     176    0.0
# 198         198         #SuaraGanjarSukses     176    0.0
# 199         199          #GanjarianSpartan     172    0.0
#
# [200 rows x 4 columns]

# %%
hashtag_ganjar['Label'].value_counts()
# Out:
# Label
# 0.0    197
# 1.0      2
# 2.0      1
# Name: count, dtype: int64

# %% [markdown]
# ######Positif

# %%
hashtag_ganjar_positif_df = hashtag_ganjar.loc[hashtag_ganjar['Label'] == 0]

hashtag_ganjar_positif = hashtag_ganjar_positif_df['hashtag'].tolist()

pattern_hashtag_ganjar_positif = '|'.join(hashtag_ganjar_positif)

result_df_ganjar_positif = result_df_ganjar.loc[result_df_ganjar['real_content'].str.contains(pattern_hashtag_ganjar_positif, case=False, na=False)]

# %%
result_df_ganjar_positif.shape
# Out:
# (603402, 18)

# %%
result_df_ganjar_positif.to_csv('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset/dav/sentiment_hashtag/result_df_ganjar_positif_v2.csv', index=False)

# %% [markdown]
# ######Negatif

# %%
hashtag_ganjar_negatif_df = hashtag_ganjar.loc[hashtag_ganjar['Label'] == 2]

hashtag_ganjar_negatif = hashtag_ganjar_negatif_df['hashtag'].tolist() + ['#ganjarblunder', '#GanjarBlunder', '#ganjargagal', '#GanjarGagal', '#UbanSokJadiJWK', '#GanjarBukanJWK', '#UbanBukanPakde', '#GanjarGakJelas', '#ganjargakjelas', '#gamausamagamud', '#bikingamud', '#ganjarbaper', '#GanjarBaper', '#ganjarantikritik', '#GanjarJKWPalsu']

pattern_hashtag_ganjar_negatif = '|'.join(hashtag_ganjar_negatif)

result_df_ganjar_negatif = result_df_ganjar.loc[result_df_ganjar['real_content'].str.contains(pattern_hashtag_ganjar_negatif, case=False, na=False)]

# %%
result_df_ganjar_negatif.shape
# Out:
# (477, 18)

# %%
result_df_ganjar_negatif.to_csv('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset/dav/sentiment_hashtag/result_df_ganjar_negatif_v2.csv', index=False)

# %% [markdown]
# ### Create Data Label Based Pretrained Model

# %% [markdown]
# ##### Anies

# %%
term_anies = ['anies', 'muhaimin', 'paslon1']

pattern_anies = '|'.join(term_anies)

buzz_df_anies = buzz_df.loc[buzz_df['content'].str.contains(pattern_anies, case=False, na=False)]

# %%
print(buzz_df_anies.shape)
# Out:
# (75924, 15)

# %%
buzz_df_anies['tcode'].value_counts()
# Out:
# tcode
# reply      50790
# mention    19352
# rt          5782
# Name: count, dtype: int64

# %%
buzz_df_anies_rt = buzz_df_anies.loc[buzz_df_anies['tcode'] == 'rt'][:2000]
buzz_df_anies_reply = buzz_df_anies.loc[buzz_df_anies['tcode'] == 'reply'][:2000]
buzz_df_anies_mention = buzz_df_anies.loc[buzz_df_anies['tcode'] == 'mention'][:2000]

buzz_df_anies_sample = pd.concat([buzz_df_anies_rt, buzz_df_anies_reply, buzz_df_anies_mention])
buzz_df_anies_sample = buzz_df_anies_sample.sample(frac=1, random_state=42).reset_index(drop=True)
buzz_df_anies_sample
# Out:
#                                                 content  \
# 0     rt desak anies hadir untuk menghargai para gen...
# 1     ahy sebaiknya diam saja. sy yakin kl pak anies...
# 2     rt 5 hasil lembaga survey terbaru jelang pilpr...
# 3     "dukungan merata dari sabang sampai merauke un...
# 4     alasan tidak memilih paslon: anies - menolak i...
# ...                                                 ...
# 5995  ah ngapain yg nyapres anies kok, bebas dong gw...
# 5996              aku mau coblos anies biar masuk surga
# 5997  alat transportasi yg smw orang punya : motor â...
# 5998  anies : ngomong apa dia? ganjar : gak tau anie...
# 5999  rt anies lebih menghargai pendukungnya, tidak ...
#
#                     created_at                                       username  \
# 0    2024-01-24 05:27:57+00:00  @WFTooYVo7HCuIdnBgiNLxas5RlHaEFMnGJtnHUcQPp0=
# 1    2024-01-09 07:07:52+00:00  @O8oNLTNtIc/d/ckMyI/uzLZB95ufb3Ie/FtmIXgzwXA=
# 2    2024-01-29 14:10:22+00:00  @FPHD9e77Jh7sGc8XkSc11/iBSZ2EJRLbjvHYXRHq0/U=
# 3    2024-01-31 08:00:36+00:00  @3BZ5t9YQpLNnrxbCUu0fMyNsiQJvLOGK0rsuo5ar2pc=
# 4    2024-01-06 02:21:42+00:00  @AinJWfBqO2Vovxg5vXPLsR58ec5MV3+3D8vRIsYe5i8=
# ...                        ...                                            ...
# 5995 2024-01-17 15:30:49+00:00  @BragVfbkZZPdySj+Lkp3KzriQjPlI4SdfuM6rq5e3nQ=
# 5996 2024-01-28 07:06:38+00:00  @cLtRFvqJPsDSOGCHVlOnrAaeEI6uSTfBZ6RGy7HkqfU=
# 5997 2024-01-20 11:31:14+00:00  @kl2YkJB121ZOq2g3xWA7IfNk4VpWlw9eK6OmiEvlIGc=
# 5998 2024-01-07 16:27:00+00:00  @wTvP5BG75J3mzG3XcVvCiBCz7OvxftgNPDa6WBPrtDM=
# 5999 2024-01-27 13:41:23+00:00  @CT0oeZbrAKOoHpA78xuDneiyD4jL4yRVXV1mQzcfHH4=
#
#         tcode  num_retweets      frn_cnt       flw_cnt       sts_cnt  \
# 0          rt            80  1651.968254   3302.777778  79339.047619
# 1       reply             0    39.000000      7.000000   1021.000000
# 2          rt             5   161.250000    379.250000   3580.750000
# 3       reply             0    49.000000     15.000000   1175.000000
# 4     mention             0   202.000000     92.000000   9765.000000
# ...       ...           ...          ...           ...           ...
# 5995    reply             0    95.000000     15.000000   4944.000000
# 5996  mention             0     5.000000     75.000000   9867.000000
# 5997  mention             0    83.000000     89.000000   3111.000000
# 5998  mention             0   126.000000     61.000000   5474.000000
# 5999       rt             3  4266.666667  12116.666667  27471.333333
#
#                         loc   lst_cnt lang  appearance_count          nama_re  \
# 0                         -  2.984127   id                63     Catatan_ali7
# 1                         -  0.000000   id                 1                -
# 2                         -  0.000000   id                 4          zputt99
# 3                         -  0.000000   id                 1                -
# 4                  Zimbabwe  0.000000   id                 1                -
# ...                     ...       ...  ...               ...              ...
# 5995                      -  0.000000   id                 1                -
# 5996  Jawa Barat, Indonesia  0.000000   id                 1                -
# 5997                      -  0.000000   id                 1                -
# 5998                      -  0.000000   id                 1                -
# 5999                      -  1.333333   id                 3  YudiSet16452924
#
#       pred_buz_xgb  pred_buz_indotweet
# 0                1                   1
# 1                1                   1
# 2                1                   1
# 3                1                   1
# 4                1                   1
# ...            ...                 ...
# 5995             1                   1
# 5996             1                   1
# 5997             1                   1
# 5998             1                   1
# 5999             1                   1
#
# [6000 rows x 15 columns]

# %%
# buzz_df_anies_sample.to_csv('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset/dav/buzz_df_anies_sample.csv', index=False)

# %% [markdown]
# ##### Prabowo

# %%
term_prabowo = ['prabowo', 'gibran', 'paslon2']

pattern_prabowo = '|'.join(term_prabowo)

buzz_df_prabowo = buzz_df.loc[buzz_df['content'].str.contains(pattern_prabowo, case=False, na=False)]

# %%
print(buzz_df_prabowo.shape)
# Out:
# (109845, 15)

# %%
buzz_df_prabowo['tcode'].value_counts()
# Out:
# tcode
# reply      72940
# mention    28674
# rt          8231
# Name: count, dtype: int64

# %%
buzz_df_prabowo_rt = buzz_df_prabowo.loc[buzz_df_prabowo['tcode'] == 'rt'][:2000]
buzz_df_prabowo_reply = buzz_df_prabowo.loc[buzz_df_prabowo['tcode'] == 'reply'][:2000]
buzz_df_prabowo_mention = buzz_df_prabowo.loc[buzz_df_prabowo['tcode'] == 'mention'][:2000]

buzz_df_prabowo_sample = pd.concat([buzz_df_prabowo_rt, buzz_df_prabowo_reply, buzz_df_prabowo_mention])
buzz_df_prabowo_sample = buzz_df_prabowo_sample.sample(frac=1, random_state=42).reset_index(drop=True)
buzz_df_prabowo_sample
# Out:
#                                                 content  \
# 0     rt elektabilitas paslon 02 lebih dari 50 perse...
# 1     "masa yang begituan ditanyain. kan udah jelas....
# 2     rt 7 potret ari lasso dapat kue ultah super be...
# 3     "anak-anak zaman now perlu lebih banyak lagi d...
# 4       anak fisip milih prabowo tuh aneh bgt kata gue.
# ...                                                 ...
# 5995  "kita tanggapi sangat positif," tutupnya. #ind...
# 5996                          all in prabowo sampe 185%
# 5997  anak hi milih prabowo peak teraneh menurut gw ...
# 5998  anies baswedan dilaporkan ke bawaslu terkait d...
# 5999  rt bedanya tukang sate gerobak (anies&ganjar) ...
#
#                     created_at                                       username  \
# 0    2024-01-31 06:19:47+00:00  @m2voMcx/feEEmc0xiYH/6QdmLSOXYIfk4AprL/RQcMk=
# 1    2024-01-05 08:07:58+00:00  @n8a93rHGzoP2nol0u7orSZeAZ3G3bvcxOUt7QFt/XDU=
# 2    2024-01-18 13:36:19+00:00  @Hpil1lH0egpq4zgZ+yqgcd5BN3imewwtXKXeDxH1kIk=
# 3    2024-01-22 04:47:37+00:00  @inefloXdBhB5hX8b4oCfYcSNX/8Asb7BGatb1rtpwHE=
# 4    2024-01-22 20:31:43+00:00  @CBSxg41Ccqd/iEi/LvrUMT9+Ba9EgMQB2ZcRzvfUYcE=
# ...                        ...                                            ...
# 5995 2024-01-31 10:08:54+00:00  @T3/Li4JTU6X+uc60OWgCOa87q5r4Rz/HV9p1Xkn4acU=
# 5996 2024-01-04 08:33:43+00:00  @n5jvpmcRI2XOEbvRUaT+mDKWMYpZ6lpjyuYrRVm9aF4=
# 5997 2024-01-25 14:27:37+00:00  @uCLCd8D0KnfazXMisZ9Me0FfaQA/K8vxYS2XVnZwswI=
# 5998 2024-01-09 04:13:06+00:00  @bOuHFJth7RzBQ5IhKFANfLwQaBHcuKCbSmKQBUnnhkU=
# 5999 2024-01-08 19:16:40+00:00  @YNJcCNDpc9ft1mZx5SbW3P1b8EEmFhlLcGya7d39vCQ=
#
#         tcode  num_retweets  frn_cnt  flw_cnt  sts_cnt        loc  lst_cnt  \
# 0          rt             2    134.0     70.0   1086.0          -      0.0
# 1       reply             0     85.8     46.0  42266.8          -      0.0
# 2          rt            10     80.4    186.1  65985.5          -      0.3
# 3       reply             0     74.2     47.4  44639.6          -      0.0
# 4     mention             0     88.0     57.0   1930.0          -      0.0
# ...       ...           ...      ...      ...      ...        ...      ...
# 5995    reply             0    100.0     37.0  37349.0          -      0.0
# 5996  mention             0    272.0     30.0   1759.0          -      0.0
# 5997  mention             0    143.0     54.0   2449.0          -      0.0
# 5998  mention             0      1.0     52.0    618.0  Indonesia      0.0
# 5999       rt             1    244.0     40.0   6529.0          -      0.0
#
#      lang  appearance_count         nama_re  pred_buz_xgb  pred_buz_indotweet
# 0      id                 1      m_sari6520             1                   1
# 1      id                 5               -             1                   1
# 2      id                10  ChairudinN6548             1                   1
# 3      id                 5               -             1                   1
# 4      id                 1               -             1                   1
# ...   ...               ...             ...           ...                 ...
# 5995   id                 1               -             1                   1
# 5996   id                 1               -             1                   1
# 5997   id                 1               -             1                   1
# 5998   id                 1               -             1                   1
# 5999   id                 1     SuryaWira88             1                   1
#
# [6000 rows x 15 columns]

# %%
# buzz_df_prabowo_sample.to_csv('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset/dav/buzz_df_prabowo_sample.csv', index=False)

# %% [markdown]
# ##### Ganjar

# %%
term_ganjar = ['ganjar', 'mahfud', 'paslon3']

pattern_ganjar = '|'.join(term_ganjar)

buzz_df_ganjar = buzz_df.loc[buzz_df['content'].str.contains(pattern_ganjar, case=False, na=False)]

# %%
print(buzz_df_ganjar.shape)
# Out:
# (340531, 15)

# %%
buzz_df_ganjar['tcode'].value_counts()
# Out:
# tcode
# mention    303644
# reply       23196
# rt          13691
# Name: count, dtype: int64

# %%
buzz_df_ganjar_rt = buzz_df_ganjar.loc[buzz_df_ganjar['tcode'] == 'rt'][:2000]
buzz_df_ganjar_reply = buzz_df_ganjar.loc[buzz_df_ganjar['tcode'] == 'reply'][:2000]
buzz_df_ganjar_mention = buzz_df_ganjar.loc[buzz_df_ganjar['tcode'] == 'mention'][:2000]

buzz_df_ganjar_sample = pd.concat([buzz_df_ganjar_rt, buzz_df_ganjar_reply, buzz_df_ganjar_mention])
buzz_df_ganjar_sample = buzz_df_ganjar_sample.sample(frac=1, random_state=42).reset_index(drop=True)
buzz_df_ganjar_sample
# Out:
#                                                 content  \
# 0     rt capres kece, ganjar pranowo mahfud md! ayo ...
# 1     asli parah bgt ini, kok kayak yakin menang ga ...
# 2     rt ajak keluarga, teman, dan tetangga untuk be...
# 3     "tolong dengarkan baik baik. apa yang disampai...
# 4     .amin dan wowo gemoysian punya wawasan, tapi g...
# ...                                                 ...
# 5995  apakah prabowo bisa tidur tadi malam habis dir...
# 5996  .amin dan wowo gemoysian mungkin terkenal, tap...
# 5997  .amin dan wowo gemoysian punya wawasan, tapi g...
# 5998  03 udahpasti #jnk #ganjarmahfudrebound #ganjar...
# 5999  rt bagi pak ganjar, pemimpin itu tdk boleh bap...
#
#                     created_at                                       username  \
# 0    2024-01-19 18:16:07+00:00  @O/KNE7rmRz8tI9eBY/tS8ybQ8iLY6kCI+iHeEA6bCUU=
# 1    2024-01-29 04:15:13+00:00  @siE6Lj8zYSAZlNpLn1QLjagJuZyTLQzt7eOB60DmgYQ=
# 2    2024-01-19 14:29:16+00:00  @yBWLrEBsJKkK5r7tdDVHnDrPJHaWBxs8m123bbiJOUM=
# 3    2024-01-26 07:58:10+00:00  @QiX5sq7s+nJDKWjwq6fjiq1jytRcuj84ckz/rQpP4cU=
# 4    2024-01-21 01:55:11+00:00  @3N38w/YIQ6iIfHl9EMFrkcPMF56jtCChairPxoCcFnA=
# ...                        ...                                            ...
# 5995 2024-01-08 05:15:04+00:00  @WQbapxy84/c3qEdadnh5gCutr++RTMDArtzktCHbtME=
# 5996 2024-01-26 05:00:22+00:00  @zyK7PcEmLDOLyqrssssazBvRjM+NHl98WvMsDp+Ac80=
# 5997 2024-01-20 23:50:13+00:00  @7ds5YBek58FSJEJzuyOkIZCv2JvZASg0YvUSLwALcn4=
# 5998 2024-01-26 17:05:20+00:00  @KL12L8y5SRFrJUH3JYfWswgPB9afxAHn5XHnjWcGqfs=
# 5999 2024-01-19 16:10:29+00:00  @VhRFodix9nOcxtSjXr041gp81M60eL2xNcyQy8j422c=
#
#         tcode  num_retweets      frn_cnt       flw_cnt        sts_cnt  \
# 0          rt             1     2.000000      1.000000     354.000000
# 1       reply             0   438.000000     88.000000    3109.000000
# 2          rt            10     4.000000      0.000000    1591.000000
# 3       reply             0    54.000000     21.000000   14211.000000
# 4     mention             0     2.000000      9.000000    4724.000000
# ...       ...           ...          ...           ...            ...
# 5995    reply             0    99.000000      5.000000     974.000000
# 5996  mention             0     1.000000      9.333333    5600.333333
# 5997  mention             0     0.500000      8.000000    4275.000000
# 5998  mention             0     0.333333      5.000000    7570.000000
# 5999       rt             8  7302.000000  16542.000000  192703.833333
#
#               loc   lst_cnt lang  appearance_count          nama_re  \
# 0               -  0.000000   id                 1  allford_gl53079
# 1       Indonesia  1.000000   id                 1                -
# 2               -  0.000000   id                 1         PutuLuzy
# 3     Dulbedul911  0.000000   id                 1                -
# 4               -  0.000000   id                 1                -
# ...           ...       ...  ...               ...              ...
# 5995            -  0.000000   id                 1                -
# 5996            -  0.000000   id                 3                -
# 5997            -  0.000000   id                 2                -
# 5998            -  0.000000   id                 3                -
# 5999            -  9.333333   id                 6        Naandaa27
#
#       pred_buz_xgb  pred_buz_indotweet
# 0                1                   1
# 1                1                   1
# 2                1                   1
# 3                1                   1
# 4                1                   1
# ...            ...                 ...
# 5995             1                   1
# 5996             1                   1
# 5997             1                   1
# 5998             1                   1
# 5999             1                   1
#
# [6000 rows x 15 columns]

# %%
# buzz_df_ganjar_sample.to_csv('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset/dav/buzz_df_ganjar_sample.csv', index=False)

# %% [markdown]
# #### Inference

# %% [markdown]
# ##### Import Test Data

# %%
import pandas as pd
import random as rn
import numpy as np
import os
import tensorflow as tf

seed_value = 42

# %%
buzz_df_anies_sample = pd.read_csv('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset/dav/buzz_df_anies_sample.csv')
buzz_df_anies_sample.shape
# Out:
# (6000, 15)

# %%
buzz_df_prabowo_sample = pd.read_csv('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset/dav/buzz_df_prabowo_sample.csv')
buzz_df_prabowo_sample.shape
# Out:
# (6000, 15)

# %%
buzz_df_ganjar_sample = pd.read_csv('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset/dav/buzz_df_ganjar_sample.csv')
buzz_df_ganjar_sample.shape
# Out:
# (6000, 15)

# %% [markdown]
# ##### Predict Test Data Anies

# %%
words_count = buzz_df_anies_sample['content'].apply(lambda x: len(x.split()))
buzz_df_anies_sample['word_count'] = words_count

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(words_count, bins=50, edgecolor='black')
plt.title('Distribution of Text Lengths')
plt.xlabel('Length of Text')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
buzz_df_anies_sample_test = buzz_df_anies_sample.loc[buzz_df_anies_sample['word_count'] < 100]
buzz_df_anies_sample_test.shape
# Out:
# (5988, 16)

# %%
from transformers import pipeline

pretrained_name = "ayameRushia/bert-base-indonesian-1.5G-sentiment-analysis-smsa"

sentiment_model = pipeline(
    "sentiment-analysis",
    model=pretrained_name,
    tokenizer=pretrained_name
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/899 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/443M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/387 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/230k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/476k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
from tqdm import tqdm

# Initialize an empty list to store predictions
predictions = []

# Set batch size for inference
batch_size = 64
test_data = buzz_df_anies_sample_test['content'].tolist()

# Use tqdm to show the progress bar
for i in tqdm(range(0, len(test_data), batch_size), desc="Inference Progress"):
    batch = test_data[i:i + batch_size]
    batch_predictions = sentiment_model(batch)
    predictions.extend(batch_predictions)
# Out:
# Inference Progress: 100%|██████████| 94/94 [20:25<00:00, 13.04s/it]

# %%
labels = [prediction['label'] for prediction in predictions]
scores = [prediction['score'] for prediction in predictions]

test_label = pd.Series(labels)
test_label.value_counts()

buzz_df_anies_sample_test['sentiment_pred'] = labels
buzz_df_anies_sample_test['sentiment_score'] = scores
# Out:
# <ipython-input-13-cc54a32d66f5>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   buzz_df_anies_sample_test['sentiment_pred'] = labels
# <ipython-input-13-cc54a32d66f5>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   buzz_df_anies_sample_test['sentiment_score'] = scores

# %%
buzz_df_anies_sample_test[:10]
# Out:
#                                              content  \
# 0  rt desak anies hadir untuk menghargai para gen...
# 1  ahy sebaiknya diam saja. sy yakin kl pak anies...
# 2  rt 5 hasil lembaga survey terbaru jelang pilpr...
# 3  "dukungan merata dari sabang sampai merauke un...
# 4  alasan tidak memilih paslon: anies - menolak i...
# 5  rt bacrit. abu janda si zionist aja ada di kub...
# 6  rt anies menerima 9 penghargaan nasional saat ...
# 7  rt . . pak anies .. anda membawa keadilan sosi...
# 8  rt cukuplah mrk menjadi saksi seorang anies ra...
# 9  rt abah memulai perubahan di sistem kampanye d...
#
#                   created_at                                       username  \
# 0  2024-01-24 05:27:57+00:00  @WFTooYVo7HCuIdnBgiNLxas5RlHaEFMnGJtnHUcQPp0=
# 1  2024-01-09 07:07:52+00:00  @O8oNLTNtIc/d/ckMyI/uzLZB95ufb3Ie/FtmIXgzwXA=
# 2  2024-01-29 14:10:22+00:00  @FPHD9e77Jh7sGc8XkSc11/iBSZ2EJRLbjvHYXRHq0/U=
# 3  2024-01-31 08:00:36+00:00  @3BZ5t9YQpLNnrxbCUu0fMyNsiQJvLOGK0rsuo5ar2pc=
# 4  2024-01-06 02:21:42+00:00  @AinJWfBqO2Vovxg5vXPLsR58ec5MV3+3D8vRIsYe5i8=
# 5  2024-01-30 05:02:51+00:00  @5oC4ynlEGajbtBKspZYuaCDbw+ngHdvvmXfpEApLEDw=
# 6  2024-01-12 16:30:02+00:00  @kfT2qe8579Df3N9T03xbtqSe1lFizE5gdOAA38H5bWg=
# 7  2024-01-21 15:23:54+00:00  @3GGuN9usEyLp5TAet4ufrxHQCJA1nBvmdfN3CJ95vPc=
# 8  2024-01-08 14:33:25+00:00  @+IW8ojJRROecki9RIfKtYz/1ruqJFg2qSnwoDE5NZJE=
# 9  2024-01-17 03:18:36+00:00  @CJVdBJfA26mxi3pq+YGutVT3qUTt2BJsIwx7Z5E0c0Y=
#
#      tcode  num_retweets      frn_cnt      flw_cnt       sts_cnt       loc  \
# 0       rt            80  1651.968254  3302.777778  79339.047619         -
# 1    reply             0    39.000000     7.000000   1021.000000         -
# 2       rt             5   161.250000   379.250000   3580.750000         -
# 3    reply             0    49.000000    15.000000   1175.000000         -
# 4  mention             0   202.000000    92.000000   9765.000000  Zimbabwe
# 5       rt             2    14.000000     0.000000     71.000000         -
# 6       rt             8  2649.625000  2916.750000  65100.750000         -
# 7       rt           231   203.000000    51.500000    945.500000         -
# 8       rt             1   440.000000   471.000000  28633.000000         -
# 9       rt            24   584.384615   422.038462  26910.346154         -
#
#     lst_cnt lang  appearance_count          nama_re  pred_buz_xgb  \
# 0  2.984127   id                63     Catatan_ali7             1
# 1  0.000000   id                 1                -             1
# 2  0.000000   id                 4          zputt99             1
# 3  0.000000   id                 1                -             1
# 4  0.000000   id                 1                -             1
# 5  0.000000   id                 1       arykunosan             1
# 6  2.875000   id                 8      bianca01403             1
# 7  0.000000   id                 2  StefanAntonio__             1
# 8  0.000000   id                 1  tigeradvan75829             1
# 9  0.538462   id                26      Roy75361813             1
#
#    pred_buz_indotweet  word_count sentiment_pred  sentiment_score
# 0                   1          44       Positive         0.916047
# 1                   1          15       Negative         0.999382
# 2                   1          26        Neutral         0.999112
# 3                   1           9        Neutral         0.845931
# 4                   1          40        Neutral         0.996314
# 5                   1          49       Negative         0.999857
# 6                   1          30        Neutral         0.591141
# 7                   1          52       Negative         0.999832
# 8                   1          12        Neutral         0.995971
# 9                   1          40       Negative         0.982094

# %%
# buzz_df_anies_sample_test.to_csv('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset/dav/buzz_df_anies_sentiment.csv', index=False)

# %% [markdown]
# ##### Predict Test Data Prabowo

# %%
words_count = buzz_df_prabowo_sample['content'].apply(lambda x: len(x.split()))
buzz_df_prabowo_sample['word_count'] = words_count

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(words_count, bins=50, edgecolor='black')
plt.title('Distribution of Text Lengths')
plt.xlabel('Length of Text')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
buzz_df_prabowo_sample_test = buzz_df_prabowo_sample.loc[buzz_df_prabowo_sample['word_count'] < 100]
buzz_df_prabowo_sample_test.shape
# Out:
# (5984, 16)

# %%
from transformers import pipeline

pretrained_name = "ayameRushia/bert-base-indonesian-1.5G-sentiment-analysis-smsa"

sentiment_model = pipeline(
    "sentiment-analysis",
    model=pretrained_name,
    tokenizer=pretrained_name
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/899 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/443M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/387 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/230k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/476k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
from tqdm import tqdm

# Initialize an empty list to store predictions
predictions = []

# Set batch size for inference
batch_size = 64
test_data = buzz_df_prabowo_sample_test['content'].tolist()

# Use tqdm to show the progress bar
for i in tqdm(range(0, len(test_data), batch_size), desc="Inference Progress"):
    batch = test_data[i:i + batch_size]
    batch_predictions = sentiment_model(batch)
    predictions.extend(batch_predictions)
# Out:
# Inference Progress: 100%|██████████| 94/94 [15:38<00:00,  9.98s/it]

# %%
labels = [prediction['label'] for prediction in predictions]
scores = [prediction['score'] for prediction in predictions]

buzz_df_prabowo_sample_test['sentiment_pred'] = labels
buzz_df_prabowo_sample_test['sentiment_score'] = scores

test_label = pd.Series(labels)
test_label.value_counts()
# Out:
# Neutral     3402
# Negative    1465
# Positive    1117
# Name: count, dtype: int64

# %%
buzz_df_prabowo_sample_test[:10]
# Out:
#                                              content  \
# 0  rt elektabilitas paslon 02 lebih dari 50 perse...
# 1  "masa yang begituan ditanyain. kan udah jelas....
# 2  rt 7 potret ari lasso dapat kue ultah super be...
# 3  "anak-anak zaman now perlu lebih banyak lagi d...
# 4    anak fisip milih prabowo tuh aneh bgt kata gue.
# 5  rt buku hitam prabowo subianto dibedah di mata...
# 6  rt bela prabowo subianto, kiky saputri ungkap ...
# 7  rt 2 pesan prabowo di hari pahlawan nasional 2...
# 8  rt dpat cawapres gibran adalah kutukn bagi pra...
# 9  rt ahy ajak menangkan prabowo subianto-gibran ...
#
#                   created_at                                       username  \
# 0  2024-01-31 06:19:47+00:00  @m2voMcx/feEEmc0xiYH/6QdmLSOXYIfk4AprL/RQcMk=
# 1  2024-01-05 08:07:58+00:00  @n8a93rHGzoP2nol0u7orSZeAZ3G3bvcxOUt7QFt/XDU=
# 2  2024-01-18 13:36:19+00:00  @Hpil1lH0egpq4zgZ+yqgcd5BN3imewwtXKXeDxH1kIk=
# 3  2024-01-22 04:47:37+00:00  @inefloXdBhB5hX8b4oCfYcSNX/8Asb7BGatb1rtpwHE=
# 4  2024-01-22 20:31:43+00:00  @CBSxg41Ccqd/iEi/LvrUMT9+Ba9EgMQB2ZcRzvfUYcE=
# 5  2023-12-31 23:04:36+00:00  @WP4N4aKz1pW6n9fmpTmqRMuUjLqmYFgwd/OLkzj0xKg=
# 6  2024-01-19 11:07:20+00:00  @81pFZ4mL0VmR/TcKVSi/rUwLj+i1GBDwQSGblwRfI6c=
# 7  2024-01-23 00:31:07+00:00  @7bstu5VuoyfSHK4aYPXj59u+Ukb50Igr8P3V2TwN3V4=
# 8  2024-01-24 13:35:59+00:00  @/Wu19PwIn4CkBe3RZNxY8tsOEKnwVwU3PL9OI/BHvZU=
# 9  2024-01-27 18:18:14+00:00  @txtQ/6FR839lBp0I2HEEtwunDXgA3PDXWxGZeeb4Rcc=
#
#      tcode  num_retweets     frn_cnt     flw_cnt       sts_cnt loc   lst_cnt  \
# 0       rt             2  134.000000   70.000000   1086.000000   -  0.000000
# 1    reply             0   85.800000   46.000000  42266.800000   -  0.000000
# 2       rt            10   80.400000  186.100000  65985.500000   -  0.300000
# 3    reply             0   74.200000   47.400000  44639.600000   -  0.000000
# 4  mention             0   88.000000   57.000000   1930.000000   -  0.000000
# 5       rt            10   80.500000  184.900000  60236.100000   -  0.300000
# 6       rt            10   51.400000   20.400000  66479.800000   -  0.000000
# 7       rt             9   86.666667  206.666667  69588.444444   -  0.333333
# 8       rt             1  615.000000  332.000000  13557.000000   -  0.000000
# 9       rt             9   49.750000   19.250000  72158.500000   -  0.000000
#
#   lang  appearance_count          nama_re  pred_buz_xgb  pred_buz_indotweet  \
# 0   id                 1       m_sari6520             1                   1
# 1   id                 5                -             1                   1
# 2   id                10   ChairudinN6548             1                   1
# 3   id                 5                -             1                   1
# 4   id                 1                -             1                   1
# 5   id                10   ChairudinN6548             1                   1
# 6   id                10      NegarakuApa             1                   1
# 7   id                 9   ChairudinN6548             1                   1
# 8   id                 1  handayani_44277             1                   1
# 9   id                 8   ChairudinN6548             1                   1
#
#    word_count sentiment_pred  sentiment_score
# 0          19        Neutral         0.999673
# 1          16        Neutral         0.999664
# 2          20        Neutral         0.999474
# 3          25       Positive         0.998219
# 4           9       Negative         0.999866
# 5          14        Neutral         0.999734
# 6          28        Neutral         0.999583
# 7          17        Neutral         0.999634
# 8          10        Neutral         0.999291
# 9          27        Neutral         0.999662

# %%
# buzz_df_prabowo_sample_test.to_csv('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset/dav/buzz_df_prabowo_sentiment.csv', index=False)

# %% [markdown]
# ##### Predict Test Data Ganjar

# %%
words_count = buzz_df_ganjar_sample['content'].apply(lambda x: len(x.split()))
buzz_df_ganjar_sample['word_count'] = words_count

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(words_count, bins=50, edgecolor='black')
plt.title('Distribution of Text Lengths')
plt.xlabel('Length of Text')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
buzz_df_ganjar_sample_test = buzz_df_ganjar_sample.loc[buzz_df_ganjar_sample['word_count'] < 100]
buzz_df_ganjar_sample_test.shape
# Out:
# (5987, 16)

# %%
from transformers import pipeline

pretrained_name = "ayameRushia/bert-base-indonesian-1.5G-sentiment-analysis-smsa"

sentiment_model = pipeline(
    "sentiment-analysis",
    model=pretrained_name,
    tokenizer=pretrained_name
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
from tqdm import tqdm

# Initialize an empty list to store predictions
predictions = []

# Set batch size for inference
batch_size = 64
test_data = buzz_df_ganjar_sample_test['content'].tolist()

# Use tqdm to show the progress bar
for i in tqdm(range(0, len(test_data), batch_size), desc="Inference Progress"):
    batch = test_data[i:i + batch_size]
    batch_predictions = sentiment_model(batch)
    predictions.extend(batch_predictions)
# Out:
# Inference Progress: 100%|██████████| 94/94 [17:35<00:00, 11.23s/it]

# %%
labels = [prediction['label'] for prediction in predictions]
scores = [prediction['score'] for prediction in predictions]

buzz_df_ganjar_sample_test['sentiment_pred'] = labels
buzz_df_ganjar_sample_test['sentiment_score'] = scores
# Out:
# <ipython-input-9-d1e9d94a319d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   buzz_df_ganjar_sample_test['sentiment_pred'] = labels
# <ipython-input-9-d1e9d94a319d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   buzz_df_ganjar_sample_test['sentiment_score'] = scores

# %%
test_label = pd.Series(labels)
test_label.value_counts()
# Out:
# Positive    2553
# Neutral     2372
# Negative    1062
# Name: count, dtype: int64

# %%
buzz_df_ganjar_sample_test[:10]
# Out:
#                                              content  \
# 0  rt capres kece, ganjar pranowo mahfud md! ayo ...
# 1  asli parah bgt ini, kok kayak yakin menang ga ...
# 2  rt ajak keluarga, teman, dan tetangga untuk be...
# 3  "tolong dengarkan baik baik. apa yang disampai...
# 4  .amin dan wowo gemoysian punya wawasan, tapi g...
# 5  rt bersama rakyat, ganjar pranowo mahfud md me...
# 6  rt bali merah menyala bersama ganjar mahfud pe...
# 7  rt 14 tps 03 aja " lewat debat tadi, aku makin...
# 8  rt capres ganjar pranowo jangan hanya jadi pen...
# 9  rt alhamdulillah, dukungan masyarakat untuk ga...
#
#                   created_at                                       username  \
# 0  2024-01-19 18:16:07+00:00  @O/KNE7rmRz8tI9eBY/tS8ybQ8iLY6kCI+iHeEA6bCUU=
# 1  2024-01-29 04:15:13+00:00  @siE6Lj8zYSAZlNpLn1QLjagJuZyTLQzt7eOB60DmgYQ=
# 2  2024-01-19 14:29:16+00:00  @yBWLrEBsJKkK5r7tdDVHnDrPJHaWBxs8m123bbiJOUM=
# 3  2024-01-26 07:58:10+00:00  @QiX5sq7s+nJDKWjwq6fjiq1jytRcuj84ckz/rQpP4cU=
# 4  2024-01-21 01:55:11+00:00  @3N38w/YIQ6iIfHl9EMFrkcPMF56jtCChairPxoCcFnA=
# 5  2024-01-23 19:00:05+00:00  @bWhrzOaHwkYpQSlOgAnj0m353gprMZswaTo8/CvEMfw=
# 6  2024-01-21 15:58:31+00:00  @Qt7mHx9Y57T8+Woev3xyhe1TD4FURMO11oztAAJuxbg=
# 7  2024-01-26 13:09:09+00:00  @lrkLxl65KhwVnmmXqer1jcILDC08pF/aQcf4HeGWgSM=
# 8  2024-01-19 16:19:40+00:00  @QhEVOwaTYpYvQzBkre8h9IQ6AuizJAJyRwQUxkbed8k=
# 9  2024-01-07 06:30:59+00:00  @a7rMkjvZbYknTFkOJdyrWnfeqHv8Mjc+4RetgCLk0oc=
#
#      tcode  num_retweets      frn_cnt       flw_cnt        sts_cnt  \
# 0       rt             1     2.000000      1.000000     354.000000
# 1    reply             0   438.000000     88.000000    3109.000000
# 2       rt            10     4.000000      0.000000    1591.000000
# 3    reply             0    54.000000     21.000000   14211.000000
# 4  mention             0     2.000000      9.000000    4724.000000
# 5       rt             3     1.000000      0.000000    2408.000000
# 6       rt             1    83.000000     12.000000     702.000000
# 7       rt            14     0.000000      0.000000    2270.785714
# 8       rt            15     0.000000      0.000000    1546.714286
# 9       rt            19  9646.538462  15433.307692  169986.076923
#
#            loc   lst_cnt lang  appearance_count          nama_re  \
# 0            -  0.000000   id                 1  allford_gl53079
# 1    Indonesia  1.000000   id                 1                -
# 2            -  0.000000   id                 1         PutuLuzy
# 3  Dulbedul911  0.000000   id                 1                -
# 4            -  0.000000   id                 1                -
# 5            -  0.000000   id                 3       gaaabbyy28
# 6        Dubai  0.000000   id                 1   novisaja198593
# 7            -  0.000000   id                14  RisnaVeraw22441
# 8            -  0.000000   id                 7       gaaabbyy28
# 9            -  6.692308   id                13        Dew0W1snu
#
#    pred_buz_xgb  pred_buz_indotweet  word_count sentiment_pred  \
# 0             1                   1          23       Positive
# 1             1                   1          34       Negative
# 2             1                   1          23        Neutral
# 3             1                   1          25        Neutral
# 4             1                   1          24       Positive
# 5             1                   1          20        Neutral
# 6             1                   1          18        Neutral
# 7             1                   1          30       Positive
# 8             1                   1          23       Positive
# 9             1                   1          32       Positive
#
#    sentiment_score
# 0         0.994729
# 1         0.999803
# 2         0.991351
# 3         0.999493
# 4         0.994156
# 5         0.999158
# 6         0.978892
# 7         0.997324
# 8         0.712705
# 9         0.996952

# %%
# buzz_df_ganjar_sample_test.to_csv('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset/dav/buzz_df_ganjar_sentiment.csv', index=False)

# %% [markdown]
# ### Train Model

# %% [markdown]
# ###### Import Data

# %%
# !pip install transformers==4.31.0
# Out:
# Collecting transformers==4.31.0
#   Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 19.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.31.0)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 46.5 MB/s eta 0:00:00
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.31.0) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.31.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.31.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.31.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.31.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.31.0) (2024.7.4)
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.41.2
#     Uninstalling transformers-4.41.2:
#       Successfully uninstalled transformers-4.41.2
# Successfully installed tokenizers-0.13.3 transformers-4.31.0

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.20.0-py3-none-any.whl (547 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 839.5 kB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (16.1.0)
# Collecting pyarrow-hotfix (from datasets)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Collecting requests>=2.32.2 (from datasets)
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 14.1 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.5 MB/s eta 0:00:00
# Collecting fsspec[http]<=2024.5.0,>=2023.1.0 (from datasets)
#   Downloading fsspec-2024.5.0-py3-none-any.whl (316 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.1/316.1 kB 19.3 MB/s eta 0:00:00
# Collecting aiohttp (from datasets)
#   Downloading aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 18.7 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets)
#   Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.5/239.5 kB 23.0 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets)
#   Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.3/124.3 kB 13.6 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets)
#   Downloading yarl-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.6/301.6 kB 25.6 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0 (from aiohttp->datasets)
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.7.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, requests, pyarrow-hotfix, multidict, fsspec, frozenlist, dill, async-timeout, yarl, multiprocess, aiosignal, aiohttp, datasets
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.6.1
#     Uninstalling fsspec-2024.6.1:
#       Successfully uninstalled fsspec-2024.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# Successfully installed aiohttp-3.9.5 aiosignal-1.3.1 async-timeout-4.0.3 datasets-2.20.0 dill-0.3.8 frozenlist-1.4.1 fsspec-2024.5.0 multidict-6.0.5 multiprocess-0.70.16 pyarrow-hotfix-0.6 requests-2.32.3 xxhash-3.4.1 yarl-1.9.4

# %%
import pandas as pd
import random as rn
import numpy as np
import os
import tensorflow as tf
seed_value = 42

# %%
resolver = tf.distribute.cluster_resolver.TPUClusterResolver()

tf.config.experimental_connect_to_cluster(resolver)
tf.tpu.experimental.initialize_tpu_system(resolver)

strategy = tf.distribute.TPUStrategy(resolver)

# %% [markdown]
# ##### Anies

# %% [markdown]
# ###### Preprocessing Data

# %%
result_df_anies_positif = pd.read_csv('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset/dav/sentiment_hashtag/result_df_anies_positif.csv')
result_df_anies_negatif = pd.read_csv('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset/dav/sentiment_hashtag/result_df_anies_negatif.csv')

# %%
anies_positif = result_df_anies_positif.sample(4000, random_state=42)
anies_negatif = result_df_anies_negatif.sample(4000, random_state=42)
anies_positif['label'] = 1
anies_negatif['label'] = 0

df_train_anies = pd.concat([anies_positif, anies_negatif])
df_train_anies = df_train_anies.sample(frac=1, random_state=42).reset_index(drop=True)
df_train_anies.drop_duplicates(subset=['content', 'username'], inplace=True)
df_train_anies['label'].value_counts()
# Out:
# label
# 0    3827
# 1    3822
# Name: count, dtype: int64

# %%
df_train_anies_positif = df_train_anies.loc[df_train_anies['label'] == 1].sample(3000, random_state=42)
df_train_anies_negatif = df_train_anies.loc[df_train_anies['label'] == 0].sample(3000, random_state=42)

df_train_anies_balanced = pd.concat([df_train_anies_positif, df_train_anies_negatif])
df_train_anies_balanced = df_train_anies_balanced.sample(frac=1, random_state=42).reset_index(drop=True)

df_train_anies_balanced['label'].value_counts()
# Out:
# label
# 1    3000
# 0    3000
# Name: count, dtype: int64

# %%
temp_df = result_df[['content', 'content_sentiment']]

df_train_anies_balanced_clean = pd.merge(df_train_anies_balanced, temp_df, on='content', how='left')
df_train_anies_balanced_clean['content_sentiment'].isnull().sum()
# Out:
# 0

# %%
df_train_anies_balanced_clean
# Out:
#                                                 content  \
# 0     idola baru grn z nih abah anies #aminsatukanin...
# 1     masyarakat juga sudah banyak yg tau kalo pak a...
# 2     wah gua takjub deh, jakarta makin hari makin h...
# 3     apk jadi penyebab kecelakaan, anies baswedan k...
# 4     gubernur yang tahu berterima kasih pasti bukan...
# ...                                                 ...
# 5995  korupsi bansos jkt belom kelar, eh mau mulai b...
# 5996  mending berpikir realistis dong! alutsista itu...
# 5997  parah, funfact! anies baswedan adalah salah sa...
# 5998  jangan cuma janji doang bro! buktiin dulu kerj...
# 5999  kekuasaan adalah nafsu bagi cak duren sehingga...
#
#                                            real_content  \
# 0     Idola baru grn z nih abah anies #AMINSatukanIn...
# 1     @s2eC3+ypWmoH9EyODFLUBniKPR054s6hp6rdwiP2AdE= ...
# 2     Wah gua takjub deh, Jakarta makin hari makin h...
# 3     APK Jadi Penyebab Kecelakaan, Anies Baswedan K...
# 4     Gubernur yang tahu berterima kasih pasti bukan...
# ...                                                 ...
# 5995  Korupsi bansos JKT belom kelar, eh mau mulai b...
# 5996  Mending berpikir realistis dong! Alutsista itu...
# 5997  Parah, Funfact! Anies Baswedan adalah salah sa...
# 5998  Jangan cuma janji doang bro! Buktiin dulu kerj...
# 5999  Kekuasaan adalah nafsu bagi cak duren sehingga...
#
#                      created_at  \
# 0     2024-01-18 02:22:03+00:00
# 1     2024-01-09 07:38:29+00:00
# 2     2024-01-01 15:06:21+00:00
# 3     2024-01-19 06:35:09+00:00
# 4     2024-01-09 10:31:03+00:00
# ...                         ...
# 5995  2024-01-01 14:39:17+00:00
# 5996  2024-01-06 21:36:00+00:00
# 5997  2024-01-05 07:38:38+00:00
# 5998  2024-01-01 15:06:10+00:00
# 5999  2024-01-06 23:02:08+00:00
#
#                                            username    tcode  num_retweets  \
# 0     @L5VR1NCD8Zl/f4vQTaqUVM3vmGP5vvWYuGfsBrQMqXg=  mention             0
# 1     @SJpmJb94301hKJDH29n9+2E8Op8Y+ocdaTMS71weT/w=    reply             0
# 2     @DeUP0RtAGiGwrJGJEX0Lk0XMh4BGkM8ZJbCi/PcCeDo=  mention             0
# 3     @ZcsDhsRzkUaRSIrKH380Q2U2n1tmiG3BDqiQrZ7pHWU=  mention             0
# 4     @jSdzMq1E/ufONOZ1Iy+/4JNV/qw3Gkr0OIeDuu7x9UQ=  mention             0
# ...                                             ...      ...           ...
# 5995  @FIT2ycJz3ATtHl8zZEs/2jfISGHoqrnfCXA2r5b33Ck=  mention             0
# 5996  @rr+gj4N5KfNe1Ujj5kNDuaoiVGUQ47wbN+vOyjHjsR0=  mention             0
# 5997  @lLN1chMUM/jPQPGVQ9J95adPURr4dTuQYsbV/31a5Ks=  mention             0
# 5998  @QWTvSwGaY8OkgATxMJRqUfBgZaRSWkrY5vp8jRlrXM4=  mention             0
# 5999  @c44Sr6tbSQlPdUS134LZFKJq4O1SqdE139D4sWqkzm0=  mention             0
#
#       frn_cnt  flw_cnt   sts_cnt        loc  lst_cnt lang  appearance_count  \
# 0       175.0     93.0    1635.0          -      0.0   id                 1
# 1         4.0      5.0     832.0          -      0.0   id                 1
# 2        14.0     15.0     259.0     Bitung      0.0   id                 1
# 3         0.0  69256.0  973442.0  Indonesia    393.0   id                 1
# 4        40.0     30.0     316.0      rahim      0.0   id                 1
# ...       ...      ...       ...        ...      ...  ...               ...
# 5995     31.0     27.0     272.0     Banjar      0.0   id                 1
# 5996     53.0     31.0     294.0          -      0.0   id                 1
# 5997      2.0      0.0     131.0          -      0.0   id                 1
# 5998     25.0     26.0     271.0   Parepare      0.0   id                 1
# 5999     12.0     22.0     317.0     Bekasi      0.0   id                 1
#
#      nama_re  label                                  content_sentiment
# 0          -      1                 idola baru grn saja nih abah anies
# 1          -      0  masyarakat juga sudah banyak yang tau kalo pak...
# 2          -      1  wah gua takjub deh, jakarta makin hari makin h...
# 3          -      1  apk jadi penyebab kecelakaan, anies baswedan k...
# 4          -      0  gubernur yang tahu berterima kasih pasti bukan...
# ...      ...    ...                                                ...
# 5995       -      0  korupsi bansos jakarta belum kelar, eh mau mul...
# 5996       -      0  mending berpikir realistis dong! alutsista itu...
# 5997       -      0  parah, funfact! anies baswedan adalah salah sa...
# 5998       -      0  jangan cuma janji doang bro! membuktikan dulu ...
# 5999       -      1  kekuasaan adalah nafsu bagi cak duren sehingga...
#
# [6000 rows x 16 columns]

# %%
from sklearn.model_selection import train_test_split

dataset = df_train_anies_balanced_clean[['content_sentiment', 'label']]

train_df, val_df = train_test_split(dataset, test_size=0.2, stratify=dataset['label'], random_state=42)

# %%
from datasets import Dataset

train = Dataset.from_pandas(train_df)
val = Dataset.from_pandas(val_df)

# %%
words_count = train_df['content_sentiment'].apply(lambda x: len(x.split()))
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(words_count, bins=50, edgecolor='black')
plt.title('Distribution of Text Lengths')
plt.xlabel('Length of Text')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
from transformers import AutoTokenizer
from datasets import load_dataset

model_checkpoint = "indolem/indobertweet-base-uncased"

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

train_data = tokenizer(train['content_sentiment'], padding='max_length', truncation=True, max_length=64, return_tensors="np")
train_data = dict(train_data)  # Because the tokenizer returns a dict subclass
train_labels = np.array(train["label"])

val_data = tokenizer(val['content_sentiment'], padding='max_length', truncation=True, max_length=64, return_tensors="np")
val_data = dict(val_data)  # Because the tokenizer returns a dict subclass
val_labels = np.array(val["label"])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.10k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/235k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
from transformers import TFAutoModelForSequenceClassification

with strategy.scope():
    model = TFAutoModelForSequenceClassification.from_pretrained(model_checkpoint, from_pt=True)

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=3e-5),
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/445M [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# The batch size will be split among TPU workers
# so we scale it up based on how many of them there are
BATCH_SIZE = 3 * strategy.num_replicas_in_sync

tf_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_labels))
tf_dataset = tf_dataset.shuffle(buffer_size=len(tf_dataset), seed=seed_value)
# You should use drop_remainder on TPU where possible, because a change in the
# batch size will require a new XLA compilation
tf_dataset = tf_dataset.batch(BATCH_SIZE, drop_remainder=True)

tf_dataset
# Out:
# <_BatchDataset element_spec=({'input_ids': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None), 'token_type_ids': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None), 'attention_mask': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None)}, TensorSpec(shape=(24,), dtype=tf.int64, name=None))>

# %%
# The batch size will be split among TPU workers
# so we scale it up based on how many of them there are
BATCH_SIZE = 3 * strategy.num_replicas_in_sync

tf_dataset_val = tf.data.Dataset.from_tensor_slices((val_data, val_labels))
tf_dataset_val = tf_dataset_val.shuffle(buffer_size=len(tf_dataset_val), seed=seed_value)
# You should use drop_remainder on TPU where possible, because a change in the
# batch size will require a new XLA compilation
tf_dataset_val = tf_dataset_val.batch(BATCH_SIZE, drop_remainder=True)

tf_dataset_val
# Out:
# <_BatchDataset element_spec=({'input_ids': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None), 'token_type_ids': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None), 'attention_mask': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None)}, TensorSpec(shape=(24,), dtype=tf.int64, name=None))>

# %%
saved_filepath = '/content/drive/MyDrive/Satria Data pt 2/Semifinal/Model/IndoTweet_24_sentiment_anies_v2/checkpoint-IndoTweet_24_sentiment_anies_v2'

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=saved_filepath,  # Path to save the model file
    monitor='val_sparse_categorical_accuracy',  # Metric to monitor
    save_best_only=True,  # Save only the best model
    mode='max',  # Mode to determine if the metric is improving (use 'min' for loss)
    save_weights_only=True,  # Save only the model weights
    verbose=1  # Verbosity mode
)

early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_sparse_categorical_accuracy',  # Metric to monitor
    patience=3,  # Number of epochs with no improvement after which training will be stopped
    mode='max',  # Mode to determine if the metric is improving (use 'min' for loss)
    verbose=1  # Verbosity mode
)

# %%
import time

start_time_serial = time.time()
model.fit(tf_dataset, epochs=5, validation_data=tf_dataset_val, callbacks=[checkpoint_callback, early_stopping_callback])
end_time_serial = time.time()
# Out:
# Epoch 1/5
# 200/200 [==============================] - ETA: 0s - loss: 0.3137 - sparse_categorical_accuracy: 0.8844
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.91167, saving model to /content/drive/MyDrive/Satria Data pt 2/Semifinal/Model/IndoTweet_24_sentiment_anies_v2/checkpoint-IndoTweet_24_sentiment_anies_v2
# 200/200 [==============================] - 102s 150ms/step - loss: 0.3137 - sparse_categorical_accuracy: 0.8844 - val_loss: 0.2638 - val_sparse_categorical_accuracy: 0.9117
# Epoch 2/5
# 200/200 [==============================] - ETA: 0s - loss: 0.1982 - sparse_categorical_accuracy: 0.9356
# Epoch 2: val_sparse_categorical_accuracy improved from 0.91167 to 0.91917, saving model to /content/drive/MyDrive/Satria Data pt 2/Semifinal/Model/IndoTweet_24_sentiment_anies_v2/checkpoint-IndoTweet_24_sentiment_anies_v2
# 200/200 [==============================] - 23s 117ms/step - loss: 0.1982 - sparse_categorical_accuracy: 0.9356 - val_loss: 0.2558 - val_sparse_categorical_accuracy: 0.9192
# Epoch 3/5
# 200/200 [==============================] - ETA: 0s - loss: 0.1514 - sparse_categorical_accuracy: 0.9533
# Epoch 3: val_sparse_categorical_accuracy did not improve from 0.91917
# 200/200 [==============================] - 18s 89ms/step - loss: 0.1514 - sparse_categorical_accuracy: 0.9533 - val_loss: 0.2790 - val_sparse_categorical_accuracy: 0.9183
# Epoch 4/5
# 200/200 [==============================] - ETA: 0s - loss: 0.1193 - sparse_categorical_accuracy: 0.9621
# Epoch 4: val_sparse_categorical_accuracy did not improve from 0.91917
# 200/200 [==============================] - 17s 83ms/step - loss: 0.1193 - sparse_categorical_accuracy: 0.9621 - val_loss: 0.3212 - val_sparse_categorical_accuracy: 0.9117
# Epoch 5/5
# 200/200 [==============================] - ETA: 0s - loss: 0.0970 - sparse_categorical_accuracy: 0.9663
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.91917
# 200/200 [==============================] - 17s 83ms/step - loss: 0.0970 - sparse_categorical_accuracy: 0.9663 - val_loss: 0.3622 - val_sparse_categorical_accuracy: 0.9125
# Epoch 5: early stopping

# %% [markdown]
# ###### Inference

# %%
from transformers import TFAutoModelForSequenceClassification

with strategy.scope():
    model = TFAutoModelForSequenceClassification.from_pretrained(model_checkpoint, from_pt=True)

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=3e-5),
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])

model.load_weights(saved_filepath)

loss, accuracy = model.evaluate(tf_dataset_val)
print(f'Validation loss: {loss}')
print(f'Validation accuracy: {accuracy}')

# %%
term_anies = ['anies', 'muhaimin', 'paslon1']

pattern_anies = '|'.join(term_anies)

result_df_anies = result_df.loc[result_df['content'].str.contains(pattern_anies, case=False, na=False)]

# %%
from datasets import Dataset

test_df = result_df_anies[['content']]

test = Dataset.from_pandas(test_df)

# %%
from transformers import AutoTokenizer
from datasets import load_dataset


model_checkpoint = "indolem/indobertweet-base-uncased"

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

test_data = tokenizer(test['content'], padding='max_length', truncation=True, max_length=64, return_tensors="np")
test_data = dict(test_data)  # Because the tokenizer returns a dict subclass
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
predictions = model.predict(test_data)
predictions
# Out:
# 15786/15786 [==============================] - 295s 18ms/step
# TFSequenceClassifierOutput(loss=None, logits=array([[-3.9483395,  4.1224422],
#        [-3.493879 ,  3.765592 ],
#        [-1.0279173,  1.7343981],
#        ...,
#        [-3.3306003,  3.6618986],
#        [-3.4334922,  3.7037306],
#        [-3.1312318,  3.4585083]], dtype=float32), hidden_states=None, attentions=None)

# %%
import pickle

with open('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Predictons/pred_indotweet_sentiment_anies.pkl', 'wb') as f:
    pickle.dump(predictions, f)

# %%
prob_pred = tf.nn.softmax(predictions.logits, axis=-1).numpy()
predicted_classes = np.argmax(prob_pred, axis=-1)
predicted_probabilities = np.max(prob_pred, axis=-1)

predicted_classes_series = pd.Series(predicted_classes)
predicted_classes_series.value_counts()
# Out:
# 1    496521
# 0      8629
# Name: count, dtype: int64

# %%
result_df_anies['pred_sentiment'] = predicted_classes
result_df_sentiment = result_df_anies.groupby('pred_sentiment').agg(
    sentiment_count = ('appearance_count', 'sum')
)
result_df_sentiment
# Out:
# <ipython-input-28-f5ccfb67e423>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df_anies['pred_sentiment'] = predicted_classes
#                 sentiment_count
# pred_sentiment
# 0                         15013
# 1                       4671046

# %% [markdown]
# ##### Prabowo

# %% [markdown]
# ###### Preprocessing Data

# %%
result_df_prabowo_positif = pd.read_csv('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset/dav/sentiment_hashtag/result_df_prabowo_positif.csv')
result_df_prabowo_negatif = pd.read_csv('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset/dav/sentiment_hashtag/result_df_prabowo_negatif.csv')

# %%
prabowo_positif = result_df_prabowo_positif.sample(4000, random_state=42)
prabowo_negatif = result_df_prabowo_negatif.sample(4000, random_state=42)
prabowo_positif['label'] = 1
prabowo_negatif['label'] = 0

df_train_prabowo = pd.concat([prabowo_positif, prabowo_negatif])
df_train_prabowo = df_train_prabowo.sample(frac=1, random_state=42).reset_index(drop=True)
df_train_prabowo.drop_duplicates(subset=['content', 'username'], inplace=True)
df_train_prabowo['label'].value_counts()
# Out:
# label
# 0    3994
# 1    3991
# Name: count, dtype: int64

# %%
df_train_prabowo_positif = df_train_prabowo.loc[df_train_prabowo['label'] == 1].sample(3000, random_state=42)
df_train_prabowo_negatif = df_train_prabowo.loc[df_train_prabowo['label'] == 0].sample(3000, random_state=42)

df_train_prabowo_balanced = pd.concat([df_train_prabowo_positif, df_train_prabowo_negatif])
df_train_prabowo_balanced = df_train_prabowo_balanced.sample(frac=1, random_state=42).reset_index(drop=True)

df_train_prabowo_balanced['label'].value_counts()
# Out:
# label
# 1    3000
# 0    3000
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

dataset = df_train_prabowo_balanced[['content', 'label']]

train_df, val_df = train_test_split(dataset, test_size=0.2, stratify=dataset['label'], random_state=42)

# %%
from datasets import Dataset

train = Dataset.from_pandas(train_df)
val = Dataset.from_pandas(val_df)

# %%
words_count = train_df['content'].apply(lambda x: len(x.split()))
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(words_count, bins=50, edgecolor='black')
plt.title('Distribution of Text Lengths')
plt.xlabel('Length of Text')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
from transformers import AutoTokenizer
from datasets import load_dataset

model_checkpoint = "indolem/indobertweet-base-uncased"

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

train_data = tokenizer(train['content'], padding='max_length', truncation=True, max_length=64, return_tensors="np")
train_data = dict(train_data)  # Because the tokenizer returns a dict subclass
train_labels = np.array(train["label"])

val_data = tokenizer(val['content'], padding='max_length', truncation=True, max_length=64, return_tensors="np")
val_data = dict(val_data)  # Because the tokenizer returns a dict subclass
val_labels = np.array(val["label"])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.10k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/235k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
from transformers import TFAutoModelForSequenceClassification

with strategy.scope():
    model = TFAutoModelForSequenceClassification.from_pretrained(model_checkpoint, from_pt=True)

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=3e-5),
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/445M [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# The batch size will be split among TPU workers
# so we scale it up based on how many of them there are
BATCH_SIZE = 3 * strategy.num_replicas_in_sync

tf_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_labels))
tf_dataset = tf_dataset.shuffle(buffer_size=len(tf_dataset), seed=seed_value)
# You should use drop_remainder on TPU where possible, because a change in the
# batch size will require a new XLA compilation
tf_dataset = tf_dataset.batch(BATCH_SIZE, drop_remainder=True)

tf_dataset
# Out:
# <_BatchDataset element_spec=({'input_ids': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None), 'token_type_ids': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None), 'attention_mask': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None)}, TensorSpec(shape=(24,), dtype=tf.int64, name=None))>

# %%
# The batch size will be split among TPU workers
# so we scale it up based on how many of them there are
BATCH_SIZE = 3 * strategy.num_replicas_in_sync

tf_dataset_val = tf.data.Dataset.from_tensor_slices((val_data, val_labels))
tf_dataset_val = tf_dataset_val.shuffle(buffer_size=len(tf_dataset_val), seed=seed_value)
# You should use drop_remainder on TPU where possible, because a change in the
# batch size will require a new XLA compilation
tf_dataset_val = tf_dataset_val.batch(BATCH_SIZE, drop_remainder=True)

tf_dataset_val
# Out:
# <_BatchDataset element_spec=({'input_ids': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None), 'token_type_ids': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None), 'attention_mask': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None)}, TensorSpec(shape=(24,), dtype=tf.int64, name=None))>

# %%
saved_filepath = '/content/drive/MyDrive/Satria Data pt 2/Semifinal/Model/IndoTweet_24_sentiment_prabowo/checkpoint-IndoTweet_24_sentiment_prabowo'

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=saved_filepath,  # Path to save the model file
    monitor='val_sparse_categorical_accuracy',  # Metric to monitor
    save_best_only=True,  # Save only the best model
    mode='max',  # Mode to determine if the metric is improving (use 'min' for loss)
    save_weights_only=True,  # Save only the model weights
    verbose=1  # Verbosity mode
)

early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_sparse_categorical_accuracy',  # Metric to monitor
    patience=3,  # Number of epochs with no improvement after which training will be stopped
    mode='max',  # Mode to determine if the metric is improving (use 'min' for loss)
    verbose=1  # Verbosity mode
)

# %%
import time

start_time_serial = time.time()
model.fit(tf_dataset, epochs=5, validation_data=tf_dataset_val, callbacks=[checkpoint_callback, early_stopping_callback])
end_time_serial = time.time()
# Out:
# Epoch 1/5
# 200/200 [==============================] - ETA: 0s - loss: 0.1506 - sparse_categorical_accuracy: 0.9454
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.97250, saving model to /content/drive/MyDrive/Satria Data pt 2/Semifinal/Model/IndoTweet_24_sentiment_prabowo/checkpoint-IndoTweet_24_sentiment_prabowo
# 200/200 [==============================] - 107s 148ms/step - loss: 0.1506 - sparse_categorical_accuracy: 0.9454 - val_loss: 0.0687 - val_sparse_categorical_accuracy: 0.9725
# Epoch 2/5
# 200/200 [==============================] - ETA: 0s - loss: 0.0601 - sparse_categorical_accuracy: 0.9750
# Epoch 2: val_sparse_categorical_accuracy improved from 0.97250 to 0.97333, saving model to /content/drive/MyDrive/Satria Data pt 2/Semifinal/Model/IndoTweet_24_sentiment_prabowo/checkpoint-IndoTweet_24_sentiment_prabowo
# 200/200 [==============================] - 24s 120ms/step - loss: 0.0601 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.0613 - val_sparse_categorical_accuracy: 0.9733
# Epoch 3/5
# 200/200 [==============================] - ETA: 0s - loss: 0.0545 - sparse_categorical_accuracy: 0.9767
# Epoch 3: val_sparse_categorical_accuracy improved from 0.97333 to 0.97417, saving model to /content/drive/MyDrive/Satria Data pt 2/Semifinal/Model/IndoTweet_24_sentiment_prabowo/checkpoint-IndoTweet_24_sentiment_prabowo
# 200/200 [==============================] - 24s 118ms/step - loss: 0.0545 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.0649 - val_sparse_categorical_accuracy: 0.9742
# Epoch 4/5
# 200/200 [==============================] - ETA: 0s - loss: 0.0385 - sparse_categorical_accuracy: 0.9833
# Epoch 4: val_sparse_categorical_accuracy improved from 0.97417 to 0.97667, saving model to /content/drive/MyDrive/Satria Data pt 2/Semifinal/Model/IndoTweet_24_sentiment_prabowo/checkpoint-IndoTweet_24_sentiment_prabowo
# 200/200 [==============================] - 23s 115ms/step - loss: 0.0385 - sparse_categorical_accuracy: 0.9833 - val_loss: 0.0471 - val_sparse_categorical_accuracy: 0.9767
# Epoch 5/5
# 200/200 [==============================] - ETA: 0s - loss: 0.0402 - sparse_categorical_accuracy: 0.9796
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.97667
# 200/200 [==============================] - 16s 81ms/step - loss: 0.0402 - sparse_categorical_accuracy: 0.9796 - val_loss: 0.0939 - val_sparse_categorical_accuracy: 0.9642

# %% [markdown]
# ###### Inference

# %%
from transformers import TFAutoModelForSequenceClassification

with strategy.scope():
    model = TFAutoModelForSequenceClassification.from_pretrained(model_checkpoint, from_pt=True)

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=3e-5),
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])

model.load_weights(saved_filepath)

loss, accuracy = model.evaluate(tf_dataset_val)
print(f'Validation loss: {loss}')
print(f'Validation accuracy: {accuracy}')
# Out:
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 50/50 [==============================] - 8s 14ms/step - loss: 0.0471 - sparse_categorical_accuracy: 0.9767
# Validation loss: 0.04709412157535553
# Validation accuracy: 0.9766666889190674

# %%
term_prabowo = ['prabowo', 'gibran', 'paslon2']

pattern_prabowo = '|'.join(term_prabowo)

result_df_prabowo = result_df.loc[result_df['content'].str.contains(pattern_prabowo, case=False, na=False)]

# %%
from datasets import Dataset

test_df = result_df_prabowo[['content']]

test = Dataset.from_pandas(test_df)

# %%
from transformers import AutoTokenizer
from datasets import load_dataset


model_checkpoint = "indolem/indobertweet-base-uncased"

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

test_data = tokenizer(test['content'], padding='max_length', truncation=True, max_length=64, return_tensors="np")
test_data = dict(test_data)  # Because the tokenizer returns a dict subclass
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
predictions = model.predict(test_data)
predictions
# Out:
# 21277/21277 [==============================] - 390s 18ms/step
# TFSequenceClassifierOutput(loss=None, logits=array([[-2.8367727 ,  3.018466  ],
#        [-0.6121435 ,  0.51776004],
#        [-2.3167195 ,  2.295831  ],
#        ...,
#        [-0.4886855 ,  0.3445019 ],
#        [-0.4886855 ,  0.3445019 ],
#        [-1.0902054 ,  1.0048926 ]], dtype=float32), hidden_states=None, attentions=None)

# %%
import pickle

with open('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Predictons/pred_indotweet_sentiment_prabowo.pkl', 'wb') as f:
    pickle.dump(predictions, f)

# %%
prob_pred = tf.nn.softmax(predictions.logits, axis=-1).numpy()
predicted_classes = np.argmax(prob_pred, axis=-1)
predicted_probabilities = np.max(prob_pred, axis=-1)

predicted_classes_series = pd.Series(predicted_classes)
predicted_classes_series.value_counts()
# Out:
# 1    483628
# 0    197211
# Name: count, dtype: int64

# %%
result_df_prabowo['pred_sentiment'] = predicted_classes
result_df_sentiment = result_df_prabowo.groupby('pred_sentiment').agg(
    sentiment_count = ('appearance_count', 'sum')
)
result_df_sentiment
# Out:
# <ipython-input-28-2c7a4294ee8a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df_prabowo['pred_sentiment'] = predicted_classes
#                 sentiment_count
# pred_sentiment
# 0                        888358
# 1                       2381175

# %% [markdown]
# ##### Ganjar

# %% [markdown]
# ###### Preprocessing Data

# %%
result_df_ganjar_positif = pd.read_csv('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset/dav/sentiment_hashtag/result_df_ganjar_positif.csv')
result_df_ganjar_negatif = pd.read_csv('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset/dav/sentiment_hashtag/result_df_ganjar_negatif.csv')

# %%
ganjar_positif = result_df_ganjar_positif.sample(4000, random_state=42)
ganjar_negatif = result_df_ganjar_negatif.copy()
ganjar_positif['label'] = 1
ganjar_negatif['label'] = 0

df_train_ganjar = pd.concat([ganjar_positif, ganjar_negatif])
df_train_ganjar = df_train_ganjar.sample(frac=1, random_state=42).reset_index(drop=True)
df_train_ganjar.drop_duplicates(subset=['content', 'username'], inplace=True)
df_train_ganjar['label'].value_counts()
# Out:
# label
# 1    3999
# 0     475
# Name: count, dtype: int64

# %%
df_train_ganjar_positif = df_train_ganjar.loc[df_train_ganjar['label'] == 1].sample(3000, random_state=42)
df_train_ganjar_negatif = df_train_ganjar.loc[df_train_ganjar['label'] == 0]

df_train_ganjar_balanced = pd.concat([df_train_ganjar_positif, df_train_ganjar_negatif])
df_train_ganjar_balanced = df_train_ganjar_balanced.sample(frac=1, random_state=42).reset_index(drop=True)

df_train_ganjar_balanced['label'].value_counts()
# Out:
# label
# 1    3000
# 0     475
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

dataset = df_train_ganjar_balanced[['content', 'label']]

train_df, val_df = train_test_split(dataset, test_size=0.2, stratify=dataset['label'], random_state=42)

# %%
from datasets import Dataset

train = Dataset.from_pandas(train_df)
val = Dataset.from_pandas(val_df)

# %%
words_count = train_df['content'].apply(lambda x: len(x.split()))
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(words_count, bins=50, edgecolor='black')
plt.title('Distribution of Text Lengths')
plt.xlabel('Length of Text')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
from transformers import AutoTokenizer
from datasets import load_dataset

model_checkpoint = "indolem/indobertweet-base-uncased"

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

train_data = tokenizer(train['content'], padding='max_length', truncation=True, max_length=64, return_tensors="np")
train_data = dict(train_data)  # Because the tokenizer returns a dict subclass
train_labels = np.array(train["label"])

val_data = tokenizer(val['content'], padding='max_length', truncation=True, max_length=64, return_tensors="np")
val_data = dict(val_data)  # Because the tokenizer returns a dict subclass
val_labels = np.array(val["label"])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
from transformers import TFAutoModelForSequenceClassification

with strategy.scope():
    model = TFAutoModelForSequenceClassification.from_pretrained(model_checkpoint, from_pt=True)

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=3e-5),
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])
# Out:
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# The batch size will be split among TPU workers
# so we scale it up based on how many of them there are
BATCH_SIZE = 3 * strategy.num_replicas_in_sync

tf_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_labels))
tf_dataset = tf_dataset.shuffle(buffer_size=len(tf_dataset), seed=seed_value)
# You should use drop_remainder on TPU where possible, because a change in the
# batch size will require a new XLA compilation
tf_dataset = tf_dataset.batch(BATCH_SIZE, drop_remainder=True)

tf_dataset
# Out:
# <_BatchDataset element_spec=({'input_ids': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None), 'token_type_ids': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None), 'attention_mask': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None)}, TensorSpec(shape=(24,), dtype=tf.int64, name=None))>

# %%
# The batch size will be split among TPU workers
# so we scale it up based on how many of them there are
BATCH_SIZE = 3 * strategy.num_replicas_in_sync

tf_dataset_val = tf.data.Dataset.from_tensor_slices((val_data, val_labels))
tf_dataset_val = tf_dataset_val.shuffle(buffer_size=len(tf_dataset_val), seed=seed_value)
# You should use drop_remainder on TPU where possible, because a change in the
# batch size will require a new XLA compilation
tf_dataset_val = tf_dataset_val.batch(BATCH_SIZE, drop_remainder=True)

tf_dataset_val
# Out:
# <_BatchDataset element_spec=({'input_ids': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None), 'token_type_ids': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None), 'attention_mask': TensorSpec(shape=(24, 64), dtype=tf.int64, name=None)}, TensorSpec(shape=(24,), dtype=tf.int64, name=None))>

# %%
saved_filepath = '/content/drive/MyDrive/Satria Data pt 2/Semifinal/Model/IndoTweet_24_sentiment_ganjar/checkpoint-IndoTweet_24_sentiment_ganjar'

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=saved_filepath,  # Path to save the model file
    monitor='val_sparse_categorical_accuracy',  # Metric to monitor
    save_best_only=True,  # Save only the best model
    mode='max',  # Mode to determine if the metric is improving (use 'min' for loss)
    save_weights_only=True,  # Save only the model weights
    verbose=1  # Verbosity mode
)

early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_sparse_categorical_accuracy',  # Metric to monitor
    patience=3,  # Number of epochs with no improvement after which training will be stopped
    mode='max',  # Mode to determine if the metric is improving (use 'min' for loss)
    verbose=1  # Verbosity mode
)

# %%
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels)
class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}
class_weights_dict
# Out:
# {0: 3.6578947368421053, 1: 0.5791666666666667}

# %%
import time

start_time_serial = time.time()
model.fit(tf_dataset, epochs=5, validation_data=tf_dataset_val, callbacks=[checkpoint_callback, early_stopping_callback], class_weight=class_weights_dict)
end_time_serial = time.time()
# Out:
# Epoch 1/5
# 115/115 [==============================] - ETA: 0s - loss: 0.0828 - sparse_categorical_accuracy: 0.9790
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.98958, saving model to /content/drive/MyDrive/Satria Data pt 2/Semifinal/Model/IndoTweet_24_sentiment_ganjar/checkpoint-IndoTweet_24_sentiment_ganjar
# 115/115 [==============================] - 98s 205ms/step - loss: 0.0828 - sparse_categorical_accuracy: 0.9790 - val_loss: 0.0274 - val_sparse_categorical_accuracy: 0.9896
# Epoch 2/5
# 115/115 [==============================] - ETA: 0s - loss: 0.0154 - sparse_categorical_accuracy: 0.9960
# Epoch 2: val_sparse_categorical_accuracy improved from 0.98958 to 0.99851, saving model to /content/drive/MyDrive/Satria Data pt 2/Semifinal/Model/IndoTweet_24_sentiment_ganjar/checkpoint-IndoTweet_24_sentiment_ganjar
# 115/115 [==============================] - 19s 170ms/step - loss: 0.0154 - sparse_categorical_accuracy: 0.9960 - val_loss: 0.0082 - val_sparse_categorical_accuracy: 0.9985
# Epoch 3/5
# 115/115 [==============================] - ETA: 0s - loss: 0.0028 - sparse_categorical_accuracy: 0.9996
# Epoch 3: val_sparse_categorical_accuracy did not improve from 0.99851
# 115/115 [==============================] - 10s 87ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9996 - val_loss: 0.0233 - val_sparse_categorical_accuracy: 0.9911
# Epoch 4/5
# 115/115 [==============================] - ETA: 0s - loss: 0.0023 - sparse_categorical_accuracy: 0.9996
# Epoch 4: val_sparse_categorical_accuracy did not improve from 0.99851
# 115/115 [==============================] - 10s 86ms/step - loss: 0.0023 - sparse_categorical_accuracy: 0.9996 - val_loss: 0.0091 - val_sparse_categorical_accuracy: 0.9970
# Epoch 5/5
# 115/115 [==============================] - ETA: 0s - loss: 0.0018 - sparse_categorical_accuracy: 0.9996
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.99851
# 115/115 [==============================] - 10s 86ms/step - loss: 0.0018 - sparse_categorical_accuracy: 0.9996 - val_loss: 0.0094 - val_sparse_categorical_accuracy: 0.9985
# Epoch 5: early stopping

# %% [markdown]
# ###### Inference

# %%
from transformers import TFAutoModelForSequenceClassification

with strategy.scope():
    model = TFAutoModelForSequenceClassification.from_pretrained(model_checkpoint, from_pt=True)

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=3e-5),
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])

model.load_weights(saved_filepath)

loss, accuracy = model.evaluate(tf_dataset_val)
print(f'Validation loss: {loss}')
print(f'Validation accuracy: {accuracy}')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 28/28 [==============================] - 7s 15ms/step - loss: 0.0082 - sparse_categorical_accuracy: 0.9985
# Validation loss: 0.008248815312981606
# Validation accuracy: 0.9985119104385376

# %%
term_ganjar = ['ganjar', 'mahfud', 'paslon3']

pattern_ganjar = '|'.join(term_ganjar)

result_df_ganjar = result_df.loc[result_df['content'].str.contains(pattern_ganjar, case=False, na=False)]

# %%
from datasets import Dataset

test_df = result_df_ganjar[['content']]

test = Dataset.from_pandas(test_df)

# %%
from transformers import AutoTokenizer
from datasets import load_dataset


model_checkpoint = "indolem/indobertweet-base-uncased"

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

test_data = tokenizer(test['content'], padding='max_length', truncation=True, max_length=64, return_tensors="np")
test_data = dict(test_data)  # Because the tokenizer returns a dict subclass
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
predictions = model.predict(test_data)
predictions
# Out:
# 28322/28322 [==============================] - 525s 18ms/step
# TFSequenceClassifierOutput(loss=None, logits=array([[-3.9209960e+00,  3.5789630e+00],
#        [ 3.2340312e-01,  2.0534294e-02],
#        [ 1.7651883e-03, -1.8827918e-01],
#        ...,
#        [-3.3953662e+00,  2.9843926e+00],
#        [-3.4963205e+00,  3.0625188e+00],
#        [-3.2659507e+00,  3.0347607e+00]], dtype=float32), hidden_states=None, attentions=None)

# %%
import pickle

with open('/content/drive/MyDrive/Satria Data pt 2/Semifinal/Predictons/pred_indotweet_sentiment_ganjar.pkl', 'wb') as f:
    pickle.dump(predictions, f)

# %%
prob_pred = tf.nn.softmax(predictions.logits, axis=-1).numpy()
predicted_classes = np.argmax(prob_pred, axis=-1)
predicted_probabilities = np.max(prob_pred, axis=-1)

predicted_classes_series = pd.Series(predicted_classes)
predicted_classes_series.value_counts()
# Out:
# 1    858898
# 0     47393
# Name: count, dtype: int64

# %%
result_df_ganjar['pred_sentiment'] = predicted_classes
result_df_sentiment = result_df_ganjar.groupby('pred_sentiment').agg(
    sentiment_count = ('appearance_count', 'sum')
)
result_df_sentiment
# Out:
# <ipython-input-34-7078df3eec56>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df_ganjar['pred_sentiment'] = predicted_classes
#                 sentiment_count
# pred_sentiment
# 0                         94750
# 1                       2779775
