# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')

folder_path = '/content/drive/MyDrive/Satria Data pt 2/Semifinal/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import networkx as nx
import glob
import pickle
import os

# %% [markdown]
# # Cek Kelengkapan

# %%
file_paths_tuple = glob.glob(folder_path + 'Dataset_Part2/surya/tuple_*.pkl')
print(len(file_paths_tuple))
print(file_paths_tuple)
# Out:
# 31
# ...

# %%
all_tuple_list = []

for file_path in file_paths_tuple:
  with open(file_path, 'rb') as f:
    tuple_list = pickle.load(f)
  all_tuple_list.extend(tuple_list)
  base_path = os.path.dirname(file_path)
  print(base_path)
  print(len(tuple_list))
  print()

print("PANJANGA TOTAL: ", len(all_tuple_list))
# Out:
# /content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset_Part2/surya
# 36722
#
# /content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset_Part2/surya
# 39573
#
# /content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset_Part2/surya
# 47079
#
# /content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset_Part2/surya
# 27124
#
# /content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset_Part2/surya
# 23515
#
# /content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset_Part2/surya
# 16611
#
# /content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset_Part2/surya
# 8271
#
# /content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset_Part2/surya
# 30963
#
# /content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset_Part2/surya
# 21116
#
# /content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset_Part2/surya
# 414353
#
# /content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset_Part2/surya
# 11642
#
# /content/drive/MyDrive/Satria Data pt 2/Semifinal/Dataset_Part2/surya
# 31718
#
# ...

# %%
with open(folder_path + 'Dataset_Part2/surya/all_tuple_list.pkl', 'wb') as f:
  pickle.dump(all_tuple_list, f)

# %% [markdown]
# # Add Edges

# %%
with open(folder_path + 'Dataset_Part2/surya/all_tuple_list.pkl', 'rb') as f:
  all_tuple_list = pickle.load(f)

print(len(all_tuple_list))
# Out:
# 1968828

# %%
print(type(all_tuple_list))
print(all_tuple_list[0])
# Out:
# <class 'list'>
# ('1000006', '1000005')

# %%
G = nx.read_gexf(folder_path + 'Dataset_Part2/surya/GRAF/all_node_graf.gexf')

# %%
print(f"Jumlah node: {G.number_of_nodes()}")
print(f"Jumlah edge: {G.number_of_edges()}")
# Out:
# Jumlah node: 2161199
# Jumlah edge: 0

# %%
G.add_edges_from(all_tuple_list)

# %%
print(f"Jumlah node: {G.number_of_nodes()}")
print(f"Jumlah edge: {G.number_of_edges()}")
# Out:
# Jumlah node: 2161199
# Jumlah edge: 1956593

# %%
nx.write_gexf(G, folder_path + 'Dataset_Part2/surya/GRAF/all_node_graph_with_edges.gexf')

# %% [markdown]
# # Calculate Fiture

# %%
G = nx.read_gexf(folder_path + 'Dataset_Part2/surya/GRAF/all_node_graph_with_edges.gexf')

# %%
import pickle

degree_centrality = nx.degree_centrality(G)

# with open(folder_path + 'Dataset_Part2/surya/Graf_Fitur/degree_centrality.pkl', 'wb') as f:
#   pickle.dump(degree_centrality, f)

# %%
print(len(degree_centrality))
# Out:
# 2161199

# %%
import pickle

eigenvector_centrality = nx.eigenvector_centrality(G)

# with open(folder_path + 'Dataset_Part2/surya/Graf_Fitur/eigenvector_centrality.pkl', 'wb') as f:
#   pickle.dump(eigenvector_centrality, f)

# %%
pagerank = nx.pagerank(G)

# with open(folder_path + 'Dataset_Part2/surya/Graf_Fitur/pagerank.pkl', 'wb') as f:
#   pickle.dump(pagerank, f)

# %%
import pickle

closeness_centrality = nx.closeness_centrality(G)

with open(folder_path + 'Dataset_Part2/surya/Graf_Fitur/closeness_centrality.pkl', 'wb') as f:
  pickle.dump(closeness_centrality, f)

# %%
import pickle

load_centrality = nx.load_centrality(G)

with open(folder_path + 'Dataset_Part2/surya/Graf_Fitur/load_centrality.pkl', 'wb') as f:
  pickle.dump(load_centrality, f)

# %%
import pickle

betweenness_centrality = nx.betweenness_centrality(G)

with open(folder_path + 'Dataset_Part2/surya/Graf_Fitur/betweenness_centrality.pkl', 'wb') as f:
  pickle.dump(betweenness_centrality, f)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-3598cb5adb04> in <cell line: 3>()
#       1 import pickle
#       2
# ----> 3 betweenness_centrality = nx.betweenness_centrality(G)
#       4
#       5 with open(folder_path + 'Dataset_Part2/surya/Graf_Fitur/betweenness_centrality.pkl', 'wb') as f:
#
# /usr/local/lib/python3.10/dist-packages/networkx/utils/decorators.py in func(_argmap__wrapper, *args, **kwargs)
#     787
#     788         def func(*args, __wrapper=None, **kwargs):
# --> 789             return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#     790
#     791         # standard function-wrapping stuff
#
# /usr/local/lib/python3.10/dist-packages/networkx/utils/decorators.py in argmap_betweenness_centrality_23(G, k, normalized, weight, endpoints, seed, backend, **backend_kwargs)
#       2 import collections
#       3 import gzip
# ...

# %%
import pickle

harmonic_centrality = nx.harmonic_centrality(G)

with open(folder_path + 'Dataset_Part2/surya/Graf_Fitur/harmonic_centrality.pkl', 'wb') as f:
  pickle.dump(harmonic_centrality, f)

# %%
import pickle

katz_centrality = nx.katz_centrality(G)

with open(folder_path + 'Dataset_Part2/surya/Graf_Fitur/katz_centrality.pkl', 'wb') as f:
  pickle.dump(katz_centrality, f)

# %%
import pickle

subgraph_centrality = nx.subgraph_centrality(G)

with open(folder_path + 'Dataset_Part2/surya/Graf_Fitur/subgraph_centrality.pkl', 'wb') as f:
  pickle.dump(subgraph_centrality, f)

# %%
pip install tqdm

# %%
from tqdm import tqdm

num_neighbors_list = []
total_appearance_count_list = []

for node in tqdm(G.nodes(), desc="Processing nodes"):
    neighbors = list(G.neighbors(node))
    num_neighbors_list.append(len(neighbors))

    total_appearance_counts = 0
    for neighbor in neighbors:
        total_appearance_counts += G.nodes[neighbor]['appearance_count']
    total_appearance_count_list.append(total_appearance_counts)
# Out:
# Processing nodes: 100%|██████████| 2161199/2161199 [00:05<00:00, 366970.04it/s]

# %%
# with open(folder_path + 'Dataset_Part2/surya/Graf_Fitur/num_neighbors_list.pkl', 'wb') as f:
#   pickle.dump(num_neighbors_list, f)

# with open(folder_path + 'Dataset_Part2/surya/Graf_Fitur/total_appearance_count_list.pkl', 'wb') as f:
#   pickle.dump(total_appearance_count_list, f)

# %%
import time
start_time = time.time()

# Rekomendasi ChatGPT
degree_centrality = nx.degree_centrality(G)
betweenness_centrality = nx.betweenness_centrality(G)
closeness_centrality = nx.closeness_centrality(G)
eigenvector_centrality = nx.eigenvector_centrality(G)
harmonic_centrality = nx.harmonic_centrality(G)
katz_centrality = nx.katz_centrality(G)
load_centrality = nx.load_centrality(G)
subgraph_centrality = nx.subgraph_centrality(G)

# Selain rekomendasi chatgpt
subgraph_centrality_exp = nx.subgraph_centrality_exp(G)
percolation_centrality = nx.percolation_centrality(G)

end_time = time.time()
print(f"Lama proses 1000 data: {end_time - start_time}")

# voterank = nx.voterank(G)
# global_reaching_centrality = nx.global_reaching_centrality(G)
# dispersion = nx.dispersion(G)
# estrada_index = nx.estrada_index(G)
# edge_load_centrality = nx.edge_load_centrality(G)
# edge_betweenness_centrality = nx.edge_betweenness_centrality(G)
# incremental_closeness_centrality = nx.incremental_closeness_centrality(G)
# current_flow_closeness_centrality = nx.current_flow_closeness_centrality(G)
# information_centrality = nx.information_centrality(G)
# current_flow_betweenness_centrality = nx.current_flow_betweenness_centrality(G)
# edge_current_flow_betweenness_centrality = nx.edge_current_flow_betweenness_centrality(G)
# approximate_current_flow_betweenness_centrality = nx.approximate_current_flow_betweenness_centrality(G)
# current_flow_betweenness_centrality_subset = nx.current_flow_betweenness_centrality_subset(G)
# edge_current_flow_betweenness_centrality_subset = nx.edge_current_flow_betweenness_centrality_subset(G)
# communicability_betweenness_centrality = nx.communicability_betweenness_centrality(G)
# group_betweenness_centrality = nx.group_betweenness_centrality(G)
# group_closeness_centrality = nx.group_closeness_centrality(G)
# group_degree_centrality = nx.group_degree_centrality(G)
# prominent_group = nx.prominent_group(G)
# local_reaching_centrality = nx.local_reaching_centrality(G)
# second_order_centrality = nx.second_order_centrality(G)
# trophic_levels = nx.trophic_levels(G)
# trophic_differences = nx.trophic_differences(G)
# trophic_incoherence_parameter = nx.trophic_incoherence_parameter(G)
# laplacian_centrality = nx.laplacian_centrality(G)

# %%
import pickle
with open(folder_path + 'Dataset_Part2/surya/Graf_Fitur/degree_centrality.pkl', 'wb') as f:
  pickle.dump(degree_centrality, f)
